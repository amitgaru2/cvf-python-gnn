# %%
import torch

from torch_geometric.nn.pool import global_mean_pool
from torch.utils.data import ConcatDataset, DataLoader, random_split, Sampler

# %%
from models_by_hand import GCNConvByHand
from helpers import CVFConfigForGCNWSuccWEIDataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
EPS = 1e-10

# %%
dataset_s_n7 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "star_graph_n7_config_rank_dataset.csv",
    "star_graph_n7_edge_index.json",
)

dataset_s_n13 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "star_graph_n13_config_rank_dataset.csv",
    "star_graph_n13_edge_index.json",
)

dataset_rr_n7 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "graph_random_regular_graph_n7_d4_config_rank_dataset.csv",
    "graph_random_regular_graph_n7_d4_edge_index.json",
)

dataset_plc_n7 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "graph_powerlaw_cluster_graph_n7_config_rank_dataset.csv",
    "graph_powerlaw_cluster_graph_n7_edge_index.json",
)

batch_size = 16

dataset_coll = [
    dataset_s_n7,
    # dataset_s_n13,
    # dataset_rr_n7,
    # dataset_plc_n7,
]

# %%
train_sizes = [int(0.95 * len(ds)) for ds in dataset_coll]
test_sizes = [len(ds) - trs for ds, trs in zip(dataset_coll, train_sizes)]

train_test_datasets = [
    random_split(ds, [tr_s, ts])
    for ds, tr_s, ts in zip(dataset_coll, train_sizes, test_sizes)
]

train_datasets = [ds[0] for ds in train_test_datasets]
test_datasets = [ds[1] for ds in train_test_datasets]

# %%
datasets = ConcatDataset(train_datasets)
print(f"Train Dataset size: {len(datasets):,}")
# Out:
# Train Dataset size: 425

# %%
class CustomBatchSampler(Sampler):
    def __init__(self, datasets: ConcatDataset, batch_size: int):
        self.datasets = datasets
        self.batch_size = batch_size

    def __iter__(self):
        last_accessed = [0] + self.datasets.cumulative_sizes[:]
        end_loop = [False for _ in range(len(self.datasets.datasets))]

        while not all(end_loop):
            for turn in range(len(self.datasets.datasets)):
                if end_loop[turn]:
                    continue

                batch_size = self.batch_size
                if (
                    last_accessed[turn] + batch_size
                    >= self.datasets.cumulative_sizes[turn]
                ):
                    batch_size = (
                        self.datasets.cumulative_sizes[turn] - last_accessed[turn]
                    )
                    end_loop[turn] = True

                yield list(range(last_accessed[turn], last_accessed[turn] + batch_size))

                last_accessed[turn] += batch_size

# %%
batch_sampler = CustomBatchSampler(datasets, batch_size=batch_size)
dataloader = DataLoader(datasets, batch_sampler=batch_sampler)

# %%
# dataloader = DataLoader(datasets, batch_size=batch_size, shuffle=True)

# %%
class VanillaGNN(torch.nn.Module):
    def __init__(self, dim_in, dim_h, dim_out):
        super().__init__()
        self.gcn1 = GCNConvByHand(dim_in, dim_h, bias=False, device=device)
        self.gcn2 = GCNConvByHand(dim_h, dim_h, bias=True, device=device)
        # self.linear1 = torch.nn.Linear(dim_h, dim_h)
        self.out = torch.nn.Linear(dim_h, dim_out)

    def forward(self, x, A):
        h = self.gcn1(x, A)
        h = torch.relu(h)
        h = self.gcn2(h, A)
        h = torch.relu(h)
        # h = self.linear1(h)
        # h = torch.relu(h)
        h = self.out(h)
        h = torch.relu(h)
        h = global_mean_pool(h, torch.zeros(h.size(1)).to(device).long())
        return h

    def fit(self, epochs):
        criterion = torch.nn.MSELoss()
        optimizer = torch.optim.Adam(self.parameters(), lr=0.01, weight_decay=0.0001)
        for epoch in range(1, epochs + 1):
            self.train()
            total_loss = 0
            count = 0
            relative_loss = 0
            for batch in dataloader:
                x = batch[0]
                y = batch[1]
                y = y.unsqueeze(-1)
                optimizer.zero_grad()
                out = self(x[0], x[1])
                loss = criterion(out, y)
                relative_loss += torch.sum(abs(y - out) / (y + EPS))
                total_loss += loss
                count += 1
                loss.backward()
                optimizer.step()

            print(
                "Training set | Epoch",
                epoch,
                "| MSE Loss:",
                round((total_loss / count).item(), 4),
                "| Relative Loss:",
                round((relative_loss / count).item(), 4),
            )

# %%
gnn = VanillaGNN(3, 4, 1).to(device)
print(gnn)
print()
print("Total parameters:", f"{sum(p.numel() for p in gnn.parameters()):,}")
print()
gnn.fit(epochs=100)
# Out:
# VanillaGNN(
#   (gcn1): GCNConvByHand(
#     (linear): Linear(in_features=3, out_features=4, bias=False)
#   )
#   (gcn2): GCNConvByHand(
#     (linear): Linear(in_features=4, out_features=4, bias=True)
#   )
#   (out): Linear(in_features=4, out_features=1, bias=True)
# )
#
# Total parameters: 37
#
# Training set | Epoch 1 | MSE Loss: 2.9435 | Relative Loss: 712597312.0
# Training set | Epoch 2 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 3 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 4 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 5 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 6 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 7 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 8 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 9 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 10 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 11 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 12 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 13 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 14 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 15 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 16 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 17 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 18 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 19 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 20 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 21 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 22 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 23 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 24 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 25 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 26 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 27 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 28 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 29 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 30 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 31 | MSE Loss: 2.9432 | Relative Loss: 4.4074
# Training set | Epoch 32 | MSE Loss: 2.9432 | Relative Loss: 1396114.625
# Training set | Epoch 33 | MSE Loss: 2.9432 | Relative Loss: 20768316.0
# Training set | Epoch 34 | MSE Loss: 2.9432 | Relative Loss: 17096802.0
# Training set | Epoch 35 | MSE Loss: 2.8924 | Relative Loss: 5126873600.0
# Training set | Epoch 36 | MSE Loss: 1.7676 | Relative Loss: 40299057152.0
# Training set | Epoch 37 | MSE Loss: 0.3205 | Relative Loss: 449536352.0
# Training set | Epoch 38 | MSE Loss: 0.1978 | Relative Loss: 204827136.0
# Training set | Epoch 39 | MSE Loss: 0.182 | Relative Loss: 166073136.0
# Training set | Epoch 40 | MSE Loss: 0.1404 | Relative Loss: 483552288.0
# Training set | Epoch 41 | MSE Loss: 0.1282 | Relative Loss: 840543040.0
# Training set | Epoch 76 | MSE Loss: 0.05 | Relative Loss: 792259520.0
# Training set | Epoch 77 | MSE Loss: 0.0501 | Relative Loss: 785910016.0
# Training set | Epoch 78 | MSE Loss: 0.0491 | Relative Loss: 804786880.0
# Training set | Epoch 79 | MSE Loss: 0.0489 | Relative Loss: 759365760.0
# Training set | Epoch 80 | MSE Loss: 0.0486 | Relative Loss: 789018944.0
# Training set | Epoch 81 | MSE Loss: 0.0484 | Relative Loss: 735211392.0
# Training set | Epoch 82 | MSE Loss: 0.0482 | Relative Loss: 738806912.0
# Training set | Epoch 83 | MSE Loss: 0.048 | Relative Loss: 741392000.0
# Training set | Epoch 84 | MSE Loss: 0.0474 | Relative Loss: 719437120.0
# Training set | Epoch 85 | MSE Loss: 0.0467 | Relative Loss: 720585088.0
# Training set | Epoch 86 | MSE Loss: 0.046 | Relative Loss: 713416960.0
# Training set | Epoch 87 | MSE Loss: 0.0458 | Relative Loss: 715626816.0
# Training set | Epoch 88 | MSE Loss: 0.0452 | Relative Loss: 697109568.0
# Training set | Epoch 89 | MSE Loss: 0.0448 | Relative Loss: 707145856.0
# Training set | Epoch 90 | MSE Loss: 0.0442 | Relative Loss: 688183680.0
# Training set | Epoch 91 | MSE Loss: 0.0432 | Relative Loss: 677638528.0
# Training set | Epoch 92 | MSE Loss: 0.0427 | Relative Loss: 677482624.0
# Training set | Epoch 93 | MSE Loss: 0.0423 | Relative Loss: 655882944.0
# Training set | Epoch 94 | MSE Loss: 0.0415 | Relative Loss: 647986752.0
# Training set | Epoch 95 | MSE Loss: 0.0403 | Relative Loss: 646520640.0
# Training set | Epoch 96 | MSE Loss: 0.0394 | Relative Loss: 615625216.0
# Training set | Epoch 97 | MSE Loss: 0.0387 | Relative Loss: 623632064.0
# Training set | Epoch 98 | MSE Loss: 0.0381 | Relative Loss: 588237504.0
# Training set | Epoch 99 | MSE Loss: 0.0374 | Relative Loss: 588642752.0
# Training set | Epoch 100 | MSE Loss: 0.0367 | Relative Loss: 564320000.0

# %% [markdown]
# # Testing

# %%
import csv

f = open("test_result_w_succ_diff_nodes.csv", "w", newline="")
csv_writer = csv.writer(f)
csv_writer.writerow(["Dataset", "Actual", "Predicted"])

criterion = torch.nn.MSELoss()

gnn.eval()

with torch.no_grad():
    test_concat_datasets = ConcatDataset(test_datasets)
    test_batch_sampler = CustomBatchSampler(test_concat_datasets, batch_size=10240)
    test_dataloader = DataLoader(test_concat_datasets, batch_sampler=test_batch_sampler)
    # test_dataloader = DataLoader(
    #     test_concat_datasets, batch_size=len(test_concat_datasets)
    # )
    total_loss = 0
    relative_loss = 0
    total_matched = 0
    count = 0
    for batch in test_dataloader:
        x = batch[0]
        y = batch[1]
        y = y.unsqueeze(-1)
        out = gnn(x[0], x[1])
        csv_writer.writerows(
            (i, j.item(), k.item())
            for (i, j, k) in zip(
                x[2], y.detach().cpu().numpy(), out.detach().cpu().numpy()
            )
        )
        loss = criterion(out, y)
        # print("Loss: ", loss)
        total_loss += loss
        relative_loss += torch.sum(abs(y - out) / (y + EPS))
        out = torch.round(out)
        matched = (out == y).sum().item()
        total_matched += matched
        count += 1

    print(
        "Test set",
        "| MSE loss:",
        round((total_loss / count).item(), 4),
        "| Relative Loss:",
        round((relative_loss / count).item(), 4),
        "| Total matched",
        total_matched,
        "out of",
        len(test_concat_datasets),
        f"(Accuracy: {round(total_matched/len(test_concat_datasets) * 100, 2)}%)",
    )

f.close()
# Out:
# Test set | MSE loss: 0.0648 | Relative Loss: 0.9003 | Total matched 21 out of 23 (Accuracy: 91.3%)

# %% [markdown]
# # Testing with Untrained Datasets

# %% [markdown]
# dataset_rr_n8 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "graph_random_regular_graph_n8_d4_config_rank_dataset.csv",
#     "graph_random_regular_graph_n8_d4_edge_index.json",
# )
#
# dataset_plc_n9 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "graph_powerlaw_cluster_graph_n9_config_rank_dataset.csv",
#     "graph_powerlaw_cluster_graph_n9_edge_index.json",
# )
#
# dataset_plc_n5 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "graph_powerlaw_cluster_graph_n5_config_rank_dataset.csv",
#     "graph_powerlaw_cluster_graph_n5_edge_index.json",
# )
#
# # dataset_s_3_n7 = CVFConfigForGCNWSuccWEIDataset(
# #     device,
# #     "star_graph_3_n7_config_rank_dataset.csv",
# #     "star_graph_3_n7_edge_index.json",
# # )
#
# dataset_s_2_n7 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "star_graph_2_n7_config_rank_dataset.csv",
#     "star_graph_2_n7_edge_index.json",
# )
#
#
# dataset = dataset_s_2_n7
#
# with torch.no_grad():
#     test_dataloader = DataLoader(dataset, batch_size=10240)
#     total_loss = 0
#     relative_loss = 0
#     total_matched = 0
#     count = 0
#     for batch in test_dataloader:
#         x = batch[0]
#         y = batch[1]
#         y = y.unsqueeze(-1)
#         out = gnn(x[0], x[1])
#         loss = criterion(out, y)
#         total_loss += loss
#         relative_loss += torch.sum(abs(y - out) / (y + EPS))
#         out = torch.round(out)
#         matched = (out == y).sum().item()
#         total_matched += matched
#         count += 1
#
#     print(
#         "Test set",
#         f"| {dataset.dataset_name}",
#         "| MSE loss:",
#         round((total_loss / count).item(), 4),
#         "| Relative Loss:",
#         round((relative_loss / count).item(), 4),
#         "| Total matched",
#         f"{total_matched:,}",
#         "out of",
#         f"{len(dataset):,}",
#         f"(Accuracy: {round(total_matched/len(dataset) * 100, 2)}%)",
#     )
