# %%
import torch

from torch_geometric.nn.pool import global_mean_pool
from torch.utils.data import ConcatDataset, DataLoader, random_split, Sampler

# %%
from models_by_hand import GCNConvByHand
from helpers import CVFConfigForGCNWSuccWEIDataset

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
EPS = 1e-10

# %%
dataset_s_n7 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "star_graph_n7_config_rank_dataset.csv",
    "star_graph_n7_edge_index.json",
)

dataset_s_n13 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "star_graph_n13_config_rank_dataset.csv",
    "star_graph_n13_edge_index.json",
)

dataset_rr_n7 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "graph_random_regular_graph_n7_d4_config_rank_dataset.csv",
    "graph_random_regular_graph_n7_d4_edge_index.json",
)

dataset_plc_n7 = CVFConfigForGCNWSuccWEIDataset(
    device,
    "graph_powerlaw_cluster_graph_n7_config_rank_dataset.csv",
    "graph_powerlaw_cluster_graph_n7_edge_index.json",
)

batch_size = 16

dataset_coll = [
    dataset_s_n7,
    # dataset_s_n13,
    # dataset_rr_n7,
    # dataset_plc_n7,
]

# %%
train_sizes = [int(0.95 * len(ds)) for ds in dataset_coll]
test_sizes = [len(ds) - trs for ds, trs in zip(dataset_coll, train_sizes)]

train_test_datasets = [
    random_split(ds, [tr_s, ts])
    for ds, tr_s, ts in zip(dataset_coll, train_sizes, test_sizes)
]

train_datasets = [ds[0] for ds in train_test_datasets]
test_datasets = [ds[1] for ds in train_test_datasets]

# %%
datasets = ConcatDataset(train_datasets)
print(f"Train Dataset size: {len(datasets):,}")
# Out:
# Train Dataset size: 425

# %%
class CustomBatchSampler(Sampler):
    def __init__(self, datasets: ConcatDataset, batch_size: int):
        self.datasets = datasets
        self.batch_size = batch_size

    def __iter__(self):
        last_accessed = [0] + self.datasets.cumulative_sizes[:]
        end_loop = [False for _ in range(len(self.datasets.datasets))]

        while not all(end_loop):
            for turn in range(len(self.datasets.datasets)):
                if end_loop[turn]:
                    continue

                batch_size = self.batch_size
                if (
                    last_accessed[turn] + batch_size
                    >= self.datasets.cumulative_sizes[turn]
                ):
                    batch_size = (
                        self.datasets.cumulative_sizes[turn] - last_accessed[turn]
                    )
                    end_loop[turn] = True

                yield list(range(last_accessed[turn], last_accessed[turn] + batch_size))

                last_accessed[turn] += batch_size

# %%
batch_sampler = CustomBatchSampler(datasets, batch_size=batch_size)
dataloader = DataLoader(datasets, batch_sampler=batch_sampler)

# %%
# dataloader = DataLoader(datasets, batch_size=batch_size, shuffle=True)

# %%
class VanillaGNN(torch.nn.Module):
    def __init__(self, dim_in, dim_h, dim_out):
        super().__init__()
        self.gcn1 = GCNConvByHand(dim_in, dim_h, bias=False, device=device)
        self.gcn2 = GCNConvByHand(dim_h, dim_h, bias=True, device=device)
        # self.linear1 = torch.nn.Linear(dim_h, dim_h)
        self.out = torch.nn.Linear(dim_h, dim_out)

    def forward(self, x, A):
        h = self.gcn1(x, A)
        h = torch.relu(h)
        h = self.gcn2(h, A)
        h = torch.relu(h)
        # h = self.linear1(h)
        # h = torch.relu(h)
        h = self.out(h)
        h = torch.relu(h)
        h = global_mean_pool(h, torch.zeros(h.size(1)).to(device).long())
        return h

    def fit(self, epochs):
        criterion = torch.nn.MSELoss()
        optimizer = torch.optim.Adam(self.parameters(), lr=0.01, weight_decay=0.0001)
        for epoch in range(1, epochs + 1):
            self.train()
            total_loss = 0
            count = 0
            relative_loss = 0
            for batch in dataloader:
                x = batch[0]
                y = batch[1]
                y = y.unsqueeze(-1)
                optimizer.zero_grad()
                out = self(x[0], x[1])
                loss = criterion(out, y)
                relative_loss += torch.sum(abs(y - out) / (y + EPS))
                total_loss += loss
                count += 1
                loss.backward()
                optimizer.step()

            print(
                "Training set | Epoch",
                epoch,
                "| MSE Loss:",
                round((total_loss / count).item(), 4),
                "| Relative Loss:",
                round((relative_loss / count).item(), 4),
            )

# %%
gnn = VanillaGNN(3, 4, 1).to(device)
print(gnn)
print()
print("Total parameters:", f"{sum(p.numel() for p in gnn.parameters()):,}")
print()
gnn.fit(epochs=100)
# Out:
# VanillaGNN(
#   (gcn1): GCNConvByHand(
#     (linear): Linear(in_features=3, out_features=4, bias=False)
#   )
#   (gcn2): GCNConvByHand(
#     (linear): Linear(in_features=4, out_features=4, bias=True)
#   )
#   (out): Linear(in_features=4, out_features=1, bias=True)
# )
#
# Total parameters: 37
#
# Training set | Epoch 1 | MSE Loss: 1.421 | Relative Loss: 42573627392.0
# Training set | Epoch 2 | MSE Loss: 0.3063 | Relative Loss: 10727856128.0
# Training set | Epoch 3 | MSE Loss: 0.2517 | Relative Loss: 278334400.0
# Training set | Epoch 4 | MSE Loss: 0.2263 | Relative Loss: 425961408.0
# Training set | Epoch 5 | MSE Loss: 0.2054 | Relative Loss: 532468256.0
# Training set | Epoch 6 | MSE Loss: 0.1867 | Relative Loss: 647192192.0
# Training set | Epoch 7 | MSE Loss: 0.1682 | Relative Loss: 750417344.0
# Training set | Epoch 8 | MSE Loss: 0.1517 | Relative Loss: 829788416.0
# Training set | Epoch 9 | MSE Loss: 0.1374 | Relative Loss: 973262144.0
# Training set | Epoch 10 | MSE Loss: 0.1261 | Relative Loss: 1062749504.0
# Training set | Epoch 11 | MSE Loss: 0.1179 | Relative Loss: 1202567808.0
# Training set | Epoch 12 | MSE Loss: 0.1116 | Relative Loss: 1356642944.0
# Training set | Epoch 13 | MSE Loss: 0.1063 | Relative Loss: 1488044288.0
# Training set | Epoch 14 | MSE Loss: 0.1016 | Relative Loss: 1578371712.0
# Training set | Epoch 15 | MSE Loss: 0.0974 | Relative Loss: 1615595776.0
# Training set | Epoch 16 | MSE Loss: 0.0937 | Relative Loss: 1706433152.0
# Training set | Epoch 17 | MSE Loss: 0.0904 | Relative Loss: 1759360512.0
# Training set | Epoch 18 | MSE Loss: 0.0873 | Relative Loss: 1762611328.0
# Training set | Epoch 19 | MSE Loss: 0.0841 | Relative Loss: 1753465088.0
# Training set | Epoch 20 | MSE Loss: 0.081 | Relative Loss: 1705253888.0
# Training set | Epoch 21 | MSE Loss: 0.0779 | Relative Loss: 1640083968.0
# Training set | Epoch 22 | MSE Loss: 0.0747 | Relative Loss: 1569472640.0
# Training set | Epoch 23 | MSE Loss: 0.0717 | Relative Loss: 1478076800.0
# Training set | Epoch 24 | MSE Loss: 0.0687 | Relative Loss: 1477052544.0
# Training set | Epoch 25 | MSE Loss: 0.0666 | Relative Loss: 1253186816.0
# Training set | Epoch 26 | MSE Loss: 0.0634 | Relative Loss: 1068012288.0
# Training set | Epoch 27 | MSE Loss: 0.0609 | Relative Loss: 1089976448.0
# Training set | Epoch 28 | MSE Loss: 0.0583 | Relative Loss: 1131832192.0
# Training set | Epoch 29 | MSE Loss: 0.0567 | Relative Loss: 1051014784.0
# Training set | Epoch 30 | MSE Loss: 0.0541 | Relative Loss: 816853376.0
# Training set | Epoch 31 | MSE Loss: 0.0518 | Relative Loss: 867715328.0
# Training set | Epoch 32 | MSE Loss: 0.0499 | Relative Loss: 862287360.0
# Training set | Epoch 33 | MSE Loss: 0.048 | Relative Loss: 835387264.0
# Training set | Epoch 34 | MSE Loss: 0.0459 | Relative Loss: 963907136.0
# Training set | Epoch 35 | MSE Loss: 0.0451 | Relative Loss: 775600960.0
# Training set | Epoch 36 | MSE Loss: 0.0431 | Relative Loss: 546758848.0
# Training set | Epoch 37 | MSE Loss: 0.0413 | Relative Loss: 610180032.0
# Training set | Epoch 38 | MSE Loss: 0.0398 | Relative Loss: 577543168.0
# Training set | Epoch 39 | MSE Loss: 0.0384 | Relative Loss: 576601536.0
# Training set | Epoch 40 | MSE Loss: 0.0372 | Relative Loss: 564876544.0
# Training set | Epoch 41 | MSE Loss: 0.0361 | Relative Loss: 563862848.0
# Training set | Epoch 42 | MSE Loss: 0.035 | Relative Loss: 515721792.0
# Training set | Epoch 43 | MSE Loss: 0.0342 | Relative Loss: 465328256.0
# Training set | Epoch 44 | MSE Loss: 0.0334 | Relative Loss: 377388000.0
# Training set | Epoch 45 | MSE Loss: 0.0327 | Relative Loss: 308753760.0
# Training set | Epoch 46 | MSE Loss: 0.0321 | Relative Loss: 303488704.0
# Training set | Epoch 47 | MSE Loss: 0.0313 | Relative Loss: 197846608.0
# Training set | Epoch 48 | MSE Loss: 0.0307 | Relative Loss: 237196560.0
# Training set | Epoch 49 | MSE Loss: 0.0301 | Relative Loss: 97211088.0
# Training set | Epoch 50 | MSE Loss: 0.0297 | Relative Loss: 302553856.0
# Training set | Epoch 51 | MSE Loss: 0.029 | Relative Loss: 11926965.0
# Training set | Epoch 52 | MSE Loss: 0.0289 | Relative Loss: 86617296.0
# Training set | Epoch 53 | MSE Loss: 0.0284 | Relative Loss: 200142096.0
# Training set | Epoch 54 | MSE Loss: 0.028 | Relative Loss: 29475110.0
# Training set | Epoch 55 | MSE Loss: 0.028 | Relative Loss: 198179008.0
# Training set | Epoch 56 | MSE Loss: 0.0277 | Relative Loss: 14888351.0
# Training set | Epoch 57 | MSE Loss: 0.0278 | Relative Loss: 136077776.0
# Training set | Epoch 58 | MSE Loss: 0.0275 | Relative Loss: 29704896.0
# Training set | Epoch 59 | MSE Loss: 0.0274 | Relative Loss: 173190224.0
# Training set | Epoch 60 | MSE Loss: 0.027 | Relative Loss: 4439789.5
# Training set | Epoch 61 | MSE Loss: 0.027 | Relative Loss: 22992220.0
# Training set | Epoch 62 | MSE Loss: 0.0267 | Relative Loss: 162394992.0
# Training set | Epoch 63 | MSE Loss: 0.0264 | Relative Loss: 9369623.0
# Training set | Epoch 64 | MSE Loss: 0.0262 | Relative Loss: 28105914.0
# Training set | Epoch 65 | MSE Loss: 0.0259 | Relative Loss: 98243888.0
# Training set | Epoch 66 | MSE Loss: 0.026 | Relative Loss: 54113756.0
# Training set | Epoch 67 | MSE Loss: 0.0261 | Relative Loss: 54274624.0
# Training set | Epoch 68 | MSE Loss: 0.0259 | Relative Loss: 63865280.0
# Training set | Epoch 69 | MSE Loss: 0.0256 | Relative Loss: 53890428.0
# Training set | Epoch 70 | MSE Loss: 0.0255 | Relative Loss: 48918772.0
# Training set | Epoch 71 | MSE Loss: 0.0253 | Relative Loss: 46057360.0
# Training set | Epoch 72 | MSE Loss: 0.0251 | Relative Loss: 47346788.0
# Training set | Epoch 73 | MSE Loss: 0.0248 | Relative Loss: 45925960.0
# Training set | Epoch 74 | MSE Loss: 0.0245 | Relative Loss: 48032620.0
# Training set | Epoch 75 | MSE Loss: 0.0242 | Relative Loss: 39460760.0
# Training set | Epoch 76 | MSE Loss: 0.024 | Relative Loss: 40031708.0
# Training set | Epoch 77 | MSE Loss: 0.0239 | Relative Loss: 42573312.0
# Training set | Epoch 78 | MSE Loss: 0.024 | Relative Loss: 43689760.0
# Training set | Epoch 79 | MSE Loss: 0.0236 | Relative Loss: 29004106.0
# Training set | Epoch 80 | MSE Loss: 0.0234 | Relative Loss: 31011098.0
# Training set | Epoch 81 | MSE Loss: 0.0235 | Relative Loss: 48646372.0
# Training set | Epoch 82 | MSE Loss: 0.0231 | Relative Loss: 24203324.0
# Training set | Epoch 83 | MSE Loss: 0.023 | Relative Loss: 22050152.0
# Training set | Epoch 84 | MSE Loss: 0.0232 | Relative Loss: 51060860.0
# Training set | Epoch 85 | MSE Loss: 0.0228 | Relative Loss: 19299668.0
# Training set | Epoch 86 | MSE Loss: 0.0229 | Relative Loss: 15180833.0
# Training set | Epoch 87 | MSE Loss: 0.0226 | Relative Loss: 49523124.0
# Training set | Epoch 88 | MSE Loss: 0.0226 | Relative Loss: 21936650.0
# Training set | Epoch 89 | MSE Loss: 0.0225 | Relative Loss: 20342270.0
# Training set | Epoch 90 | MSE Loss: 0.0224 | Relative Loss: 36096616.0
# Training set | Epoch 91 | MSE Loss: 0.0224 | Relative Loss: 31727748.0
# Training set | Epoch 92 | MSE Loss: 0.0222 | Relative Loss: 23105408.0
# Training set | Epoch 93 | MSE Loss: 0.0222 | Relative Loss: 25659644.0
# Training set | Epoch 94 | MSE Loss: 0.022 | Relative Loss: 32688116.0
# Training set | Epoch 95 | MSE Loss: 0.0221 | Relative Loss: 25143844.0
# Training set | Epoch 96 | MSE Loss: 0.0218 | Relative Loss: 25103022.0
# Training set | Epoch 97 | MSE Loss: 0.0219 | Relative Loss: 23174416.0
# Training set | Epoch 98 | MSE Loss: 0.0218 | Relative Loss: 33340928.0
# Training set | Epoch 99 | MSE Loss: 0.0215 | Relative Loss: 18402532.0
# Training set | Epoch 100 | MSE Loss: 0.0217 | Relative Loss: 22877674.0

# %% [markdown]
# # Testing

# %%
import csv
import datetime


f = open(f"test_results/test_result_w_succ_diff_nodes_gcn__{datetime.datetime.now().strftime("%Y_%m_%d_%H_%M")}.csv", "w", newline="")
csv_writer = csv.writer(f)
csv_writer.writerow(["Dataset", "Actual", "Predicted"])

criterion = torch.nn.MSELoss()

gnn.eval()

with torch.no_grad():
    test_concat_datasets = ConcatDataset(test_datasets)
    test_batch_sampler = CustomBatchSampler(test_concat_datasets, batch_size=10240)
    test_dataloader = DataLoader(test_concat_datasets, batch_sampler=test_batch_sampler)

    total_loss = 0
    relative_loss = 0
    total_matched = 0
    count = 0
    for batch in test_dataloader:
        x = batch[0]
        y = batch[1]
        y = y.unsqueeze(-1)
        out = gnn(x[0], x[1])
        csv_writer.writerows(
            (i, j.item(), k.item())
            for (i, j, k) in zip(
                x[2], y.detach().cpu().numpy(), out.detach().cpu().numpy()
            )
        )
        loss = criterion(out, y)
        total_loss += loss
        relative_loss += torch.sum(abs(y - out) / (y + EPS))
        out = torch.round(out)
        matched = (out == y).sum().item()
        total_matched += matched
        count += 1

    print(
        "Test set",
        "| MSE loss:",
        round((total_loss / count).item(), 4),
        "| Relative Loss:",
        round((relative_loss / count).item(), 4),
        "| Total matched",
        total_matched,
        "out of",
        len(test_concat_datasets),
        f"(Accuracy: {round(total_matched/len(test_concat_datasets) * 100, 2)}%)",
    )

f.close()
# Out:
# Test set | MSE loss: 0.0397 | Relative Loss: 0.54 | Total matched 22 out of 23 (Accuracy: 95.65%)

# %% [markdown]
# # Testing with Untrained Datasets

# %% [markdown]
# dataset_rr_n8 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "graph_random_regular_graph_n8_d4_config_rank_dataset.csv",
#     "graph_random_regular_graph_n8_d4_edge_index.json",
# )
#
# dataset_plc_n9 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "graph_powerlaw_cluster_graph_n9_config_rank_dataset.csv",
#     "graph_powerlaw_cluster_graph_n9_edge_index.json",
# )
#
# dataset_plc_n5 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "graph_powerlaw_cluster_graph_n5_config_rank_dataset.csv",
#     "graph_powerlaw_cluster_graph_n5_edge_index.json",
# )
#
# # dataset_s_3_n7 = CVFConfigForGCNWSuccWEIDataset(
# #     device,
# #     "star_graph_3_n7_config_rank_dataset.csv",
# #     "star_graph_3_n7_edge_index.json",
# # )
#
# dataset_s_2_n7 = CVFConfigForGCNWSuccWEIDataset(
#     device,
#     "star_graph_2_n7_config_rank_dataset.csv",
#     "star_graph_2_n7_edge_index.json",
# )
#
#
# dataset = dataset_s_2_n7
#
# with torch.no_grad():
#     test_dataloader = DataLoader(dataset, batch_size=10240)
#     total_loss = 0
#     relative_loss = 0
#     total_matched = 0
#     count = 0
#     for batch in test_dataloader:
#         x = batch[0]
#         y = batch[1]
#         y = y.unsqueeze(-1)
#         out = gnn(x[0], x[1])
#         loss = criterion(out, y)
#         total_loss += loss
#         relative_loss += torch.sum(abs(y - out) / (y + EPS))
#         out = torch.round(out)
#         matched = (out == y).sum().item()
#         total_matched += matched
#         count += 1
#
#     print(
#         "Test set",
#         f"| {dataset.dataset_name}",
#         "| MSE loss:",
#         round((total_loss / count).item(), 4),
#         "| Relative Loss:",
#         round((relative_loss / count).item(), 4),
#         "| Total matched",
#         f"{total_matched:,}",
#         "out of",
#         f"{len(dataset):,}",
#         f"(Accuracy: {round(total_matched/len(dataset) * 100, 2)}%)",
#     )
