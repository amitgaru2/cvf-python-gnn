# %%
import seaborn as sns

from collections import Counter

# %%
data = open("chosen.txt", "r").read().split(" ")

# %%
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
Counter(data)
# Out:
# Counter({'15': 52633,
#          '14': 52633,
#          '17': 52633,
#          '18': 52633,
#          '4': 52632,
#          '7': 52632,
#          '3': 52632,
#          '13': 52632,
#          '16': 52632,
#          '11': 52631,
#          '12': 52631,
#          '1': 52631,
#          '2': 52631,
#          '8': 52631,
#          '5': 52631,
#          '6': 52631,
#          '10': 52630,
#          '9': 52630,
#          '19': 26316,
#          '0': 26315,
#          '': 1})
