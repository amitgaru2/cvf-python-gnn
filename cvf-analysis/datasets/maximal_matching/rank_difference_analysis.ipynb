# %%
import pandas as pd

# %%
df_n5 = pd.read_csv("star_graph_n8_config_rank_dataset.csv")
print("Mean", df_n5["rank"].mean())
print("Max", df_n5["rank"].max())
# Out:
# Mean 9.004920959472656
# Max 18

# %%
df_n6 = pd.read_csv("implicit_graph_n6_config_rank_dataset.csv")
print("Mean", df_n6["rank"].mean())
print("Max", df_n6["rank"].max())
print("Relative mean diff", df_n6["rank"].mean() - df_n5["rank"].mean())
print("Relative max diff", df_n6["rank"].max() - df_n5["rank"].max())
# Out:
# Mean 13.621399176954732
# Max 27
# Relative mean diff 6.905349794238683
# Relative max diff 12

# %%
df_n7 = pd.read_csv("implicit_graph_n7_config_rank_dataset.csv")
print("Mean", df_n7["rank"].mean())
print("Max", df_n7["rank"].max())
print("Relative mean diff", df_n7["rank"].mean() - df_n6["rank"].mean())
print("Relative max diff", df_n7["rank"].max() - df_n6["rank"].max())
# Out:
# Mean 23.246913580246915
# Max 45
# Relative mean diff 9.625514403292183
# Relative max diff 18

# %%
df_n8 = pd.read_csv("implicit_graph_n8_config_rank_dataset.csv")
print("Mean", df_n8["rank"].mean())
print("Max", df_n8["rank"].max())
print("Relative mean diff", df_n8["rank"].mean() - df_n7["rank"].mean())
print("Relative max diff", df_n8["rank"].max() - df_n7["rank"].max())
# Out:
# Mean 35.29858253315044
# Max 63
# Relative mean diff 12.051668952903523
# Relative max diff 18

# %%
df_n9 = pd.read_csv("implicit_graph_n9_config_rank_dataset.csv")
print("Mean", df_n9["rank"].mean())
print("Max", df_n9["rank"].max())
print("Relative mean diff", df_n9["rank"].mean() - df_n8["rank"].mean())
print("Relative max diff", df_n9["rank"].max() - df_n8["rank"].max())
# Out:
# Mean 49.44901691815272
# Max 84
# Relative mean diff 14.150434385002285
# Relative max diff 21

# %%
df_n10 = pd.read_csv("implicit_graph_n10_config_rank_dataset.csv")
print("Mean", df_n10["rank"].mean())
print("Max", df_n10["rank"].max())
print("Relative mean diff", df_n10["rank"].mean() - df_n9["rank"].mean())
print("Relative max diff", df_n10["rank"].max() - df_n9["rank"].max())
# Out:
# Mean 65.54244779759183
# Max 111
# Relative mean diff 16.09343087943911
# Relative max diff 27

# %%
df_n11 = pd.read_csv("implicit_graph_n11_config_rank_dataset.csv")
print("Mean", df_n11["rank"].mean())
print("Max", df_n11["rank"].max())
print("Relative mean diff", df_n11["rank"].mean() - df_n10["rank"].mean())
print("Relative max diff", df_n11["rank"].max() - df_n10["rank"].max())
# Out:
# Mean 83.4529966637877
# Max 136
# Relative mean diff 17.910548866195867
# Relative max diff 25
