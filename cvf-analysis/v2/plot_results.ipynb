# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import pandas as pd

# %%
results_dir = "coloring"
results_dir = "coloring"
results_dir = "maximal_matching"
results_dir = "maximal_independent_set"

# %%
filename = "rank_effects_by_node_avg__graph_random_regular_graph_n10_d4"

# %%
df = pd.read_csv(f"results/{results_dir}/{filename}.csv")

# %%
df
# Out:
#    node  -5   -3   -1    1    3  5
# 0     0   0  105  407  407  105  0
# 1     1   5   83  424  424   83  5
# 2     2   8  101  403  403  101  8
# 3     3   8  101  403  403  101  8
# 4     4   6   85  421  421   85  6
# 5     5   6   85  421  421   85  6
# 6     6   5   83  424  424   83  5
# 7     7   6   85  421  421   85  6
# 8     8   6   85  421  421   85  6
# 9     9   0  105  407  407  105  0

# %%
dft = df.transpose()
dft.drop(['node'], inplace=True)
dft = dft.add_prefix('Node_')
dft
# Out:
#     Node_0  Node_1  Node_2  Node_3  Node_4  Node_5  Node_6  Node_7  Node_8  \
# -5       0       5       8       8       6       6       5       6       6
# -3     105      83     101     101      85      85      83      85      85
# -1     407     424     403     403     421     421     424     421     421
# 1      407     424     403     403     421     421     424     421     421
# 3      105      83     101     101      85      85      83      85      85
# 5        0       5       8       8       6       6       5       6       6
#
#     Node_9
# -5       0
# -3     105
# -1     407
# 1      407
# 3      105
# 5        0

# %%
# columns = ['Node_0', 'Node_4', 'Node_7', 'Node_9']
columns = ['Node_1', 'Node_3', 'Node_5', 'Node_8']

dft = dft[columns]
dft
# Out:
#     Node_1  Node_3  Node_5  Node_8
# -5       5       8       6       6
# -3      83     101      85      85
# -1     424     403     421     421
# 1      424     403     421     421
# 3       83     101      85      85
# 5        5       8       6       6

# %%
plt.ioff()
plt.figure(figsize=(20, 8))

# %%
plt.ioff()
ax = sns.lineplot(dft, linewidth=2, markersize=10)

# %%
markers = ('.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')

# %%
for i, line in enumerate(ax.lines):
    line.set_marker(markers[i % len(dft.columns)])

# %%
def parse_filename(filename):
    graph_type, graph = filename.split('__')
    return f"Full Analysis - Program: {results_dir} | Graph: {graph} | Type: {graph_type}"

# %%
plt.legend()
plt.title(parse_filename(filename))
plt.xlabel("Rank Effect (-ve/+ve)")
plt.ylabel("Count")
# plt.show()
plt.savefig(f"plots/{results_dir}/full_analysis__{filename}.png", dpi=500)
