# %%
import networkx as nx

graph = "graph_16"

# create empty graph
G = nx.Graph()

# open file and read line by line
with open(f"{graph}.txt", "r") as f:
    for line in f:
        numbers = list(map(int, line.strip().split()))
        node = numbers[0]         # first number is the node
        neighbors = numbers[1:]   # rest are neighbors
        
        for neighbor in neighbors:
            G.add_edge(node, neighbor)

# check
print("Nodes:", G.nodes())
print("Edges:", G.edges())
# Out:
# Nodes: [0, 1, 2, 3, 4, 5, 6, 7]
# Edges: [(0, 1), (1, 2), (1, 3), (3, 4), (3, 5), (5, 6), (5, 7)]

# %%
def print_dict_sorted_by_values(d: dict):
    for key, value in sorted(d.items(), key=lambda item: item[1], reverse=True):
        print(f"{key}: {value}")

# %%
def print_dict_sorted(d: dict):
    for key in sorted(d.keys()):
        print(f"{d[key]}")

# %%
degree_centrality = nx.degree_centrality(G)
print_dict_sorted(degree_centrality), print(), print_dict_sorted_by_values(degree_centrality)
# Out:
# 0.14285714285714285
# 0.42857142857142855
# 0.14285714285714285
# 0.42857142857142855
# 0.14285714285714285
# 0.42857142857142855
# 0.14285714285714285
# 0.14285714285714285
#
# 1: 0.42857142857142855
# 3: 0.42857142857142855
# 5: 0.42857142857142855
# 0: 0.14285714285714285
# 2: 0.14285714285714285
# 4: 0.14285714285714285
# 6: 0.14285714285714285
# 7: 0.14285714285714285
# (None, None, None)

# %%
closeness_centrality = nx.closeness_centrality(G)
print_dict_sorted(closeness_centrality), print(), print_dict_sorted_by_values(closeness_centrality)
# Out:
# 0.3684210526315789
# 0.5384615384615384
# 0.3684210526315789
# 0.6363636363636364
# 0.4117647058823529
# 0.5384615384615384
# 0.3684210526315789
# 0.3684210526315789
#
# 3: 0.6363636363636364
# 1: 0.5384615384615384
# 5: 0.5384615384615384
# 4: 0.4117647058823529
# 0: 0.3684210526315789
# 2: 0.3684210526315789
# 6: 0.3684210526315789
# 7: 0.3684210526315789
# (None, None, None)

# %%
betweenness_centrality = nx.betweenness_centrality(G)
print_dict_sorted(betweenness_centrality), print(), print_dict_sorted_by_values(betweenness_centrality)
# Out:
# 0.0
# 0.5238095238095237
# 0.0
# 0.7142857142857142
# 0.0
# 0.5238095238095237
# 0.0
# 0.0
#
# 3: 0.7142857142857142
# 1: 0.5238095238095237
# 5: 0.5238095238095237
# 0: 0.0
# 2: 0.0
# 4: 0.0
# 6: 0.0
# 7: 0.0
# (None, None, None)

# %%
eigenvector_centrality = nx.eigenvector_centrality(G)
print_dict_sorted(eigenvector_centrality), print(), print_dict_sorted_by_values(eigenvector_centrality)
# Out:
# 0.21758193016676425
# 0.46470570082180035
# 0.21758193016676425
# 0.5573440694752514
# 0.26095445220924324
# 0.46470570082180035
# 0.21758193016676425
# 0.21758193016676425
#
# 3: 0.5573440694752514
# 1: 0.46470570082180035
# 5: 0.46470570082180035
# 4: 0.26095445220924324
# 0: 0.21758193016676425
# 2: 0.21758193016676425
# 6: 0.21758193016676425
# 7: 0.21758193016676425
# (None, None, None)

# %%
pagerank = nx.pagerank(G, alpha=0.85)
print_dict_sorted(pagerank), print(), print_dict_sorted_by_values(pagerank)
# Out:
# 0.07745031133862629
# 0.20717586942555055
# 0.07745031133862629
# 0.20033571230840042
# 0.07551130348599312
# 0.20717586942555055
# 0.07745031133862632
# 0.07745031133862632
#
# 1: 0.20717586942555055
# 5: 0.20717586942555055
# 3: 0.20033571230840042
# 6: 0.07745031133862632
# 7: 0.07745031133862632
# 0: 0.07745031133862629
# 2: 0.07745031133862629
# 4: 0.07551130348599312
# (None, None, None)

# %%
katz_centrality = nx.katz_centrality(G, alpha=0.1, beta=1.0)
print_dict_sorted(katz_centrality), print(), print_dict_sorted_by_values(katz_centrality)
# Out:
# 0.32647840908438397
# 0.39237865022734253
# 0.32647840908438397
# 0.3984245186646346
# 0.32708299592811324
# 0.39237865022734253
# 0.32647840908438397
# 0.32647840908438397
#
# 3: 0.3984245186646346
# 1: 0.39237865022734253
# 5: 0.39237865022734253
# 4: 0.32708299592811324
# 0: 0.32647840908438397
# 2: 0.32647840908438397
# 6: 0.32647840908438397
# 7: 0.32647840908438397
# (None, None, None)

# %%
harmonic_centrality = nx.harmonic_centrality(G)
print_dict_sorted(harmonic_centrality), print(), print_dict_sorted_by_values(harmonic_centrality)
# Out:
# 3.166666666666667
# 4.666666666666666
# 3.166666666666667
# 5.0
# 3.3333333333333335
# 4.666666666666666
# 3.1666666666666665
# 3.1666666666666665
#
# 3: 5.0
# 1: 4.666666666666666
# 5: 4.666666666666666
# 4: 3.3333333333333335
# 0: 3.166666666666667
# 2: 3.166666666666667
# 6: 3.1666666666666665
# 7: 3.1666666666666665
# (None, None, None)

# %%
pagerank = nx.pagerank(G, alpha=0.90)
print_dict_sorted(pagerank), print(), print_dict_sorted_by_values(pagerank)
# Out:
# ---------------------------------------------------------------------------
# PowerIterationFailedConvergence           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pagerank = nx.pagerank(G, alpha=0.90)
#       2 print_dict_sorted(pagerank), print(), print_dict_sorted_by_values(pagerank)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 26:3, in argmap_pagerank_23(G, alpha, personalization, max_iter, tol, nstart, weight, dangling, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# File ~/anaconda3/envs/cvf/lib/python3.13/site-packages/networkx/utils/backends.py:633, in _dispatchable.__call__(self, backend, *args, **kwargs)
#     628 """Returns the result of the original function, or the backend function if
#     629 the backend is specified and that backend implements `func`."""
#     631 if not backends:
#     632     # Fast path if no backends are installed
# --> 633     return self.orig_func(*args, **kwargs)
#     635 # Use `backend_name` in this function instead of `backend`
#     636 backend_name = backend
#
# File ~/anaconda3/envs/cvf/lib/python3.13/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py:110, in pagerank(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#       9 @nx._dispatchable(edge_attrs="weight")
#      10 def pagerank(
#      11     G,
#    (...)     18     dangling=None,
#      19 ):
#      20     """Returns the PageRank of the nodes in the graph.
#      21
#      22     PageRank computes a ranking of the nodes in the graph G based on
#    (...)    108
#     109     """
# --> 110     return _pagerank_scipy(
#     111         G, alpha, personalization, max_iter, tol, nstart, weight, dangling
#     112     )
#
# File ~/anaconda3/envs/cvf/lib/python3.13/site-packages/networkx/algorithms/link_analysis/pagerank_alg.py:499, in _pagerank_scipy(G, alpha, personalization, max_iter, tol, nstart, weight, dangling)
#     497     if err < N * tol:
#     498         return dict(zip(nodelist, map(float, x)))
# --> 499 raise nx.PowerIterationFailedConvergence(max_iter)
#
# PowerIterationFailedConvergence: (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 100 iterations')
