# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from algorithm_gd import forward, loss_fn, r2_score, gradient_m, gradient_c, get_iteration_vs_accuracy_data

# %%
X = [1, 1, 1, 2, 2, 2, 3, 3, 3,  5, 5, 5, 6, 6, 6, 7,7, 7,  9, 9, 9, 10, 10, 10, 11, 11, 11]
y = [2, 2.25, 1.75, 2, 2.25, 1.75, 2, 2.25, 1.75, 6, 6.25, 5.75, 6, 6.25, 5.75, 6, 6.25, 5.75,  10, 9.75, 10.25, 10, 9.75, 10.25, 10, 9.75, 10.25]

# %%
# df = pd.read_csv("SOCR-HeightWeight.csv")
# df.rename(columns={"Height(Inches)": "X", "Weight(Pounds)": "y"}, inplace=True)
# X = df['X'].array
# y = df['y'].array

# %%
L0 = 0

# %%
m = 0
step_m = 0.1
c = 0

# %%
iterations = 100

# %%
def newton_raphson_L(L0, m_pred, m, grad_m):
    def f_L(L):
        return m_pred - m + L * grad_m

    def f_L_der(L):
        return grad_m

    numerator = f_L(L0)
    denominator = f_L_der(L0)

    while numerator != 0:
        new_L0 = L0 - numerator/denominator
        numerator = f_L(new_L0)
        denominator = f_L_der(new_L0)
        if abs(new_L0 - L0) <= 0.00001:
            L0 = new_L0
            break
        L0 = new_L0

    return L0

# %%
params = {"m": m, "c": c}
X_test = X
y_test = y
y_test_mean = sum(y_test)/len(y_test)

# %%
L = L0
for i in range(1, iterations + 1):
    y_pred = forward(X, params)
    y_test_pred = forward(X_test, params)

    # accuracy = r2_score(y_test, y_test_mean, y_test_pred)

    grad_m = gradient_m(X, y, y_pred)
    # print("gradient", grad_m)
    
    grad_c = gradient_c(y, y_pred)

    # L0 = L
    
    m_pred = m + step_m
    L_add = newton_raphson_L(L0, m_pred, m, grad_m)

    m_pred = m - step_m
    L_sub = newton_raphson_L(L0, m_pred, m, grad_m)

    # print("L_add =", L_add, "L_sub =", L_sub)

    if L_add <= 0 and L_sub <= 0:
        break
    elif L_add >= 0 and L_sub >= 0:
        L = min(L_add, L_sub)
    elif L_add <= 0:
        L = L_sub
    else:
        L = L_add

    print("L =", L)

    m = m - L * grad_m
    c = c - L * grad_c

    print("m =", m)

    params = {"m": m, "c": c}
    print()
# Out:
# L = 0.0010714285714285715
# m = 0.1
#
# L = 0.0011945664292702905
# m = 0.2
#
# L = 0.0013496867300775638
# m = 0.30000000000000004
#
# L = 0.0015511102485102975
# m = 0.4
#
# L = 0.0018232082764082999
# m = 0.5
#
# L = 0.00221109640078916
# m = 0.6
#
# L = 0.0028086742239347255
# m = 0.7
#
# L = 0.003849001965002678
# m = 0.7999999999999999
#
# L = 0.006113898236942052
# m = 0.8999999999999999
#
# L = 0.014861846503808788
# m = 0.9999999999999999
#
# L = 0.034360889396565834
# m = 0.8999999999999999
#
# L = 0.015004309068206935
# m = 0.9999999999999999
#
# L = 0.03362580444000807
# m = 0.8999999999999999
#
# L = 0.015144421809517302
# m = 0.9999999999999999
#
# L = 0.032945609932625484
# m = 0.8999999999999999
#
# L = 0.015282327394531212
# m = 0.9999999999999999
#
# L = 0.032314001919633024
# m = 0.8999999999999999
#
# L = 0.01541815039802056
# m = 0.9999999999999999
#
# L = 0.031725648315648135
# m = 0.8999999999999999
#
# L = 0.015552000144598663
# m = 0.9999999999999999
#
# L = 0.031176004008586486
# m = 0.8999999999999999
#
# L = 0.01568397300778678
# m = 0.9999999999999999
#
# L = 0.030661167277722313
# m = 0.8999999999999999
#
# L = 0.015814154288139183
# m = 0.9999999999999999
#
# L = 0.030177767027926086
# m = 0.8999999999999999
#
# L = 0.015942619761196125
# m = 0.9999999999999999
#
# L = 0.02972287330759277
# m = 0.8999999999999999
#
# L = 0.016069436963756706
# m = 0.9999999999999999
#
# L = 0.02929392562745632
# m = 0.8999999999999999
#
# L = 0.01619466627076935
# m = 0.9999999999999999
#
# L = 0.02888867503661853
# m = 0.8999999999999999
#
# L = 0.016318361803206928
# m = 0.9999999999999999
#
# L = 0.02850513693725034
# m = 0.8999999999999999
#
# L = 0.01644057219839706
# m = 0.9999999999999999
#
# L = 0.02814155235939217
# m = 0.8999999999999999
#
# L = 0.016561341267571323
# m = 0.9999999999999999
#
# L = 0.02779635595801165
# m = 0.8999999999999999
#
# L = 0.016680708560285768
# m = 0.9999999999999999
#
# L = 0.02746814939412074
# m = 0.8999999999999999
#
# L = 0.01679870985143383
# m = 0.9999999999999999
#
# L = 0.027155679060257787
# m = 0.8999999999999999
#
# L = 0.01691537756352266
# m = 0.9999999999999999
#
# L = 0.026857817335806868
# m = 0.8999999999999999
#
# L = 0.017030741134494765
# m = 0.9999999999999999
#
# L = 0.02657354672903595
# m = 0.8999999999999999
#
# L = 0.017144827339493695
# m = 0.9999999999999999
#
# L = 0.026301946394353123
# m = 0.8999999999999999
#
# L = 0.01725766057347662
# m = 0.9999999999999999
#
# L = 0.026042180615159095
# m = 0.8999999999999999
#
# L = 0.017369263100378743
# m = 0.9999999999999999
#
# L = 0.02579348892213616
# m = 0.8999999999999999
#
# L = 0.01747965527357004
# m = 0.9999999999999999
#
# L = 0.0255551775792348
# m = 0.8999999999999999
#
# L = 0.017588855731565402
# m = 0.9999999999999999
#
# L = 0.025326612218985647
# m = 0.8999999999999999
#
# L = 0.01769688157231093
# m = 0.9999999999999999
#
# L = 0.025107211448056957
# m = 0.8999999999999999
#
# L = 0.017803748508849845
# m = 0.9999999999999999
#
# L = 0.024896441275439857
# m = 0.8999999999999999
#
# L = 0.01790947100874052
# m = 0.9999999999999999
#
# L = 0.024693810240980964
# m = 0.8999999999999999
#
# L = 0.018014062419245625
# m = 0.9999999999999999
#
# L = 0.0244988651424989
# m = 0.8999999999999999
#
# L = 0.018117535080014464
# m = 0.9999999999999999
#
# L = 0.024311187276419403
# m = 0.8999999999999999
#
# L = 0.01821990042473597
# m = 0.9999999999999999
#
# L = 0.024130389120521116
# m = 0.8999999999999999
#
# L = 0.018321169073031683
# m = 0.9999999999999999
#
# L = 0.023956111398608253
# m = 0.8999999999999999
#
# L = 0.018421350913684766
# m = 0.9999999999999999
#
# L = 0.023788020476189515
# m = 0.8999999999999999
#
# L = 0.018520455180154678
# m = 0.9999999999999999
#
# L = 0.02362580604392406
# m = 0.8999999999999999
#
# L = 0.018618490519201156
# m = 0.9999999999999999
#
# L = 0.023469179051985326
# m = 0.8999999999999999
#
# L = 0.018715465053337238
# m = 0.9999999999999999
#
# L = 0.02331786986383716
# m = 0.8999999999999999
#
# L = 0.018811386437738036
# m = 0.9999999999999999
#
# L = 0.023171626602396213
# m = 0.8999999999999999
#
# L = 0.018906261912157402
# m = 0.9999999999999999
#
# L = 0.023030213665324237
# m = 0.8999999999999999
#
# L = 0.01900009834833533
# m = 0.9999999999999999
#
# L = 0.022893410389382914
# m = 0.8999999999999999
#
# L = 0.01909290229332368
# m = 0.9999999999999999
#
# L = 0.022761009846479205
# m = 0.8999999999999999
#
# L = 0.019184680009107724
# m = 0.9999999999999999
#
# L = 0.02263281775632852
# m = 0.8999999999999999
#
# L = 0.019275437508857386
# m = 0.9999999999999999
#
# L = 0.022508651502616824
# m = 0.8999999999999999
#
# L = 0.019365180590106258
# m = 0.9999999999999999
#
# L = 0.022388339241218806
# m = 0.8999999999999999
#
# L = 0.019453914865123212
# m = 0.9999999999999999
#
# L = 0.022271719090464992
# m = 0.8999999999999999
#
# L = 0.019541645788713185
# m = 0.9999999999999999
#
# L = 0.022158638394684304
# m = 0.8999999999999999
#
# L = 0.01962837868365968
# m = 0.9999999999999999
#
# L = 0.02204895305331507
# m = 0.8999999999999999
#
# L = 0.019714118763999425
# m = 0.9999999999999999
#
# L = 0.021942526908797784
# m = 0.8999999999999999
#
# L = 0.01979887115630077
# m = 0.9999999999999999

# %%
# _ = get_iteration_vs_accuracy_data(X, y, 1000, L=0.001)
