# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from algorithm_gd import forward, loss_fn, r2_score, gradient_m, gradient_c, get_iteration_vs_accuracy_data

# %%
X = [1, 1, 1, 2, 2, 2, 3, 3, 3,  5, 5, 5, 6, 6, 6, 7,7, 7,  9, 9, 9, 10, 10, 10, 11, 11, 11]
y = [2, 2.25, 1.75, 2, 2.25, 1.75, 2, 2.25, 1.75, 6, 6.25, 5.75, 6, 6.25, 5.75, 6, 6.25, 5.75,  10, 9.75, 10.25, 10, 9.75, 10.25, 10, 9.75, 10.25]

# %%
# df = pd.read_csv("SOCR-HeightWeight.csv")
# df.rename(columns={"Height(Inches)": "X", "Weight(Pounds)": "y"}, inplace=True)
# X = df['X'].array
# y = df['y'].array

# %%
L0 = 0

# %%
m = 0
step_m = 0.1
c = 0

# %%
iterations = 100

# %%
def newton_raphson_L(L0, m_pred, m, grad_m):
    def f_L(L):
        return m_pred - m + L * grad_m

    def f_L_der(L):
        return grad_m

    numerator = f_L(L0)
    denominator = f_L_der(L0)

    while numerator != 0:
        new_L0 = L0 - numerator/denominator
        numerator = f_L(new_L0)
        denominator = f_L_der(new_L0)
        if abs(new_L0 - L0) <= 0.00001:
            L0 = new_L0
            break
        L0 = new_L0

    return L0

# %%
params = {"m": m, "c": c}
X_test = X
y_test = y
y_test_mean = sum(y_test)/len(y_test)

# %%
L = L0
for i in range(1, iterations + 1):
    y_pred = forward(X, params)
    y_test_pred = forward(X_test, params)

    # accuracy = r2_score(y_test, y_test_mean, y_test_pred)

    grad_m = gradient_m(X, y, y_pred)
    # print("gradient", grad_m)
    
    grad_c = gradient_c(y, y_pred)

    # L0 = L
    
    m_pred = m + step_m
    L_add = newton_raphson_L(L0, m_pred, m, grad_m)

    m_pred = m - step_m
    L_sub = newton_raphson_L(L0, m_pred, m, grad_m)

    # print("L_add =", L_add, "L_sub =", L_sub)

    if L_add <= 0 and L_sub <= 0:
        break
    elif L_add >= 0 and L_sub >= 0:
        L = min(L_add, L_sub)
    elif L_add <= 0:
        L = L_sub
    else:
        L = L_add

    print("L =", L)

    m = m - L * grad_m
    c = c - L * grad_c

    print("m =", m)

    params = {"m": m, "c": c}
    print()
# Out:
# L = 0.0010714285714285715
# m = 0.1
#
# L = 0.0011945664292702905
# m = 0.2
#
# L = 0.0013496867300775638
# m = 0.30000000000000004
#
# L = 0.0015511102485102975
# m = 0.4
#
# L = 0.0018232082764082999
# m = 0.5
#
# L = 0.00221109640078916
# m = 0.6
#
# L = 0.0028086742239347255
# m = 0.7
#
# L = 0.003849001965002678
# m = 0.7999999999999999
#
# L = 0.006113898236942052
# m = 0.8999999999999999
#
# L = 0.014861846503808788
# m = 0.9999999999999999
#
# L = 0.034360889396565834
# m = 0.8999999999999999
#
# L = 0.015004309068206935
# m = 0.9999999999999999
#
# L = 0.03362580444000807
# m = 0.8999999999999999
#
# L = 0.015144421809517302
# m = 0.9999999999999999
#
# L = 0.032945609932625484
# m = 0.8999999999999999
#
# L = 0.015282327394531212
# m = 0.9999999999999999
#
# L = 0.032314001919633024
# m = 0.8999999999999999
#
# L = 0.01541815039802056
# m = 0.9999999999999999
#
# L = 0.031725648315648135
# m = 0.8999999999999999
#
# L = 0.015552000144598663
# m = 0.9999999999999999
#
# L = 0.031176004008586486
# m = 0.8999999999999999
#
# L = 0.01568397300778678
# m = 0.9999999999999999
#
# L = 0.030661167277722313
# m = 0.8999999999999999
#
# L = 0.015814154288139183
# m = 0.9999999999999999
#
# L = 0.030177767027926086
# m = 0.8999999999999999
#
# L = 0.015942619761196125
# m = 0.9999999999999999
#
# L = 0.02972287330759277
# m = 0.8999999999999999
#
# L = 0.016069436963756706
# m = 0.9999999999999999
#
# L = 0.02929392562745632
# m = 0.8999999999999999
#
# L = 0.01619466627076935
# m = 0.9999999999999999
#
# L = 0.02888867503661853
# m = 0.8999999999999999
#
# L = 0.016318361803206928
# m = 0.9999999999999999
#
# L = 0.02850513693725034
# m = 0.8999999999999999
#
# L = 0.01644057219839706
# m = 0.9999999999999999
#
# L = 0.02814155235939217
# m = 0.8999999999999999
#
# L = 0.016561341267571323
# m = 0.9999999999999999
#
# L = 0.02779635595801165
# m = 0.8999999999999999
#
# L = 0.016680708560285768
# m = 0.9999999999999999
#
# L = 0.02746814939412074
# m = 0.8999999999999999
#
# L = 0.01679870985143383
# m = 0.9999999999999999
#
# L = 0.027155679060257787
# m = 0.8999999999999999
#
# L = 0.01691537756352266
# m = 0.9999999999999999
#
# L = 0.026857817335806868
# m = 0.8999999999999999
#
# L = 0.017030741134494765
# m = 0.9999999999999999
#
# L = 0.02657354672903595
# m = 0.8999999999999999
#
# L = 0.017144827339493695
# m = 0.9999999999999999
#
# L = 0.026301946394353123
# m = 0.8999999999999999
#
# L = 0.01725766057347662
# m = 0.9999999999999999
#
# L = 0.026042180615159095
# m = 0.8999999999999999
#
# L = 0.017369263100378743
# m = 0.9999999999999999
#
# L = 0.02579348892213616
# m = 0.8999999999999999
#
# L = 0.01747965527357004
# m = 0.9999999999999999
#
# L = 0.0255551775792348
# m = 0.8999999999999999
#
# L = 0.017588855731565402
# m = 0.9999999999999999
#
# L = 0.025326612218985647
# m = 0.8999999999999999
#
# L = 0.01769688157231093
# m = 0.9999999999999999
#
# L = 0.025107211448056957
# m = 0.8999999999999999
#
# L = 0.017803748508849845
# m = 0.9999999999999999
#
# L = 0.024896441275439857
# m = 0.8999999999999999
#
# L = 0.01790947100874052
# m = 0.9999999999999999
#
# L = 0.024693810240980964
# m = 0.8999999999999999
#
# L = 0.018014062419245625
# m = 0.9999999999999999
#
# L = 0.0244988651424989
# m = 0.8999999999999999
#
# L = 0.018117535080014464
# m = 0.9999999999999999
#
# L = 0.024311187276419403
# m = 0.8999999999999999
#
# L = 0.01821990042473597
# m = 0.9999999999999999
#
# L = 0.024130389120521116
# m = 0.8999999999999999
#
# L = 0.018321169073031683
# m = 0.9999999999999999
#
# L = 0.023956111398608253
# m = 0.8999999999999999
#
# L = 0.018421350913684766
# m = 0.9999999999999999
#
# L = 0.023788020476189515
# m = 0.8999999999999999
#
# L = 0.018520455180154678
# m = 0.9999999999999999
#
# L = 0.02362580604392406
# m = 0.8999999999999999
#
# L = 0.018618490519201156
# m = 0.9999999999999999
#
# L = 0.023469179051985326
# m = 0.8999999999999999
#
# L = 0.018715465053337238
# m = 0.9999999999999999
#
# L = 0.02331786986383716
# m = 0.8999999999999999
#
# L = 0.018811386437738036
# m = 0.9999999999999999
#
# L = 0.023171626602396213
# m = 0.8999999999999999
#
# L = 0.018906261912157402
# m = 0.9999999999999999
#
# L = 0.023030213665324237
# m = 0.8999999999999999
#
# L = 0.01900009834833533
# m = 0.9999999999999999
#
# L = 0.022893410389382914
# m = 0.8999999999999999
#
# L = 0.01909290229332368
# m = 0.9999999999999999
#
# L = 0.022761009846479205
# m = 0.8999999999999999
#
# L = 0.019184680009107724
# m = 0.9999999999999999
#
# L = 0.02263281775632852
# m = 0.8999999999999999
#
# L = 0.019275437508857386
# m = 0.9999999999999999
#
# L = 0.022508651502616824
# m = 0.8999999999999999
#
# L = 0.019365180590106258
# m = 0.9999999999999999
#
# L = 0.022388339241218806
# m = 0.8999999999999999
#
# L = 0.019453914865123212
# m = 0.9999999999999999
#
# L = 0.022271719090464992
# m = 0.8999999999999999
#
# L = 0.019541645788713185
# m = 0.9999999999999999
#
# L = 0.022158638394684304
# m = 0.8999999999999999
#
# L = 0.01962837868365968
# m = 0.9999999999999999
#
# L = 0.02204895305331507
# m = 0.8999999999999999
#
# L = 0.019714118763999425
# m = 0.9999999999999999
#
# L = 0.021942526908797784
# m = 0.8999999999999999
#
# L = 0.01979887115630077
# m = 0.9999999999999999
#
# L = 0.021839231187259566
# m = 0.8999999999999999
#
# L = 0.019882640919100553
# m = 0.9999999999999999
#
# L = 0.02173894398669643
# m = 0.8999999999999999
#
# L = 0.019965433060639803
# m = 0.9999999999999999
#
# L = 0.021641549807959477
# m = 0.8999999999999999
#
# L = 0.02004725255502584
# m = 0.9999999999999999
#
# L = 0.021546939124380972
# m = 0.8999999999999999
#
# L = 0.02012810435693557
# m = 0.9999999999999999
#
# L = 0.021455007986335786
# m = 0.8999999999999999
#
# L = 0.020207993414966513
# m = 0.9999999999999999
#
# L = 0.021365657657436945
# m = 0.8999999999999999
#
# L = 0.02028692468373089
# m = 0.9999999999999999
#
# L = 0.021278794279419474
# m = 0.8999999999999999
#
# L = 0.020364903134782366
# m = 0.9999999999999999
#
# L = 0.021194328563078995
# m = 0.8999999999999999
#
# L = 0.02044193376645535
# m = 0.9999999999999999
#
# L = 0.021112175502905277
# m = 0.8999999999999999
#
# L = 0.020518021612692592
# m = 0.9999999999999999
#
# L = 0.021032254113295307
# m = 0.8999999999999999
#
# L = 0.020593171750929277
# m = 0.9999999999999999
#
# L = 0.02095448718444513
# m = 0.8999999999999999
#
# L = 0.020667389309097936
# m = 0.9999999999999999
#
# L = 0.020878801056208974
# m = 0.8999999999999999
#
# L = 0.02074067947181256
# m = 0.9999999999999999
#
# L = 0.020805125408385798
# m = 0.8999999999999999
#
# L = 0.02081304748578794
# m = 0.9999999999999999
#
# L = 0.020733393066041054
# m = 0.8999999999999999
#
# L = 0.020884498664543887
# m = 0.9999999999999999
#
# L = 0.020663539818608138
# m = 0.8999999999999999
#
# L = 0.02095503839244343
# m = 0.9999999999999999
#
# L = 0.020595504251631345
# m = 0.8999999999999999
#
# L = 0.021024672128108393
# m = 0.9999999999999999
#
# L = 0.020529227590120616
# m = 0.8999999999999999
#
# L = 0.021093405407254563
# m = 0.9999999999999999
#
# L = 0.02046465355258282
# m = 0.8999999999999999
#
# L = 0.021161243844985668
# m = 0.9999999999999999
#
# L = 0.02040172821488089
# m = 0.8999999999999999
#
# L = 0.021228193137582375
# m = 0.9999999999999999
#
# L = 0.020340399883148376
# m = 0.8999999999999999
#
# L = 0.02129425906382137
# m = 0.9999999999999999
#
# L = 0.020280618975056265
# m = 0.8999999999999999
#
# L = 0.021359447485856636
# m = 0.9999999999999999
#
# L = 0.020222337908791337
# m = 0.8999999999999999
#
# L = 0.021423764349693845
# m = 0.9999999999999999
#
# L = 0.02016551099916054
# m = 0.8999999999999999
#
# L = 0.021487215685286765
# m = 0.9999999999999999
#
# L = 0.020110094360287913
# m = 0.8999999999999999
#
# L = 0.02154980760628304
# m = 0.9999999999999999
#
# L = 0.02005604581441412
# m = 0.8999999999999999
#
# L = 0.021611546309445173
# m = 0.9999999999999999
#
# L = 0.020003324806352116
# m = 0.8999999999999999
#
# L = 0.021672438073771463
# m = 0.9999999999999999
#
# L = 0.019951892323187923
# m = 0.8999999999999999
#
# L = 0.021732489259339797
# m = 0.9999999999999999
#
# L = 0.01990171081885093
# m = 0.8999999999999999
#
# L = 0.021791706305896646
# m = 0.9999999999999999
#
# L = 0.01985274414320796
# m = 0.8999999999999999
#
# L = 0.021850095731211862
# m = 0.9999999999999999
#
# L = 0.019804957475362973
# m = 0.8999999999999999
#
# L = 0.02190766412921931
# m = 0.9999999999999999
#
# L = 0.019758317260871044
# m = 0.8999999999999999
#
# L = 0.021964418167961953
# m = 0.9999999999999999
#
# L = 0.019712791152597088
# m = 0.8999999999999999
#
# L = 0.022020364587359554
# m = 0.9999999999999999
#
# L = 0.019668347954971216
# m = 0.8999999999999999
#
# L = 0.022075510196815317
# m = 0.9999999999999999
#
# L = 0.019624957571411934
# m = 0.8999999999999999
#
# L = 0.02212986187267847
# m = 0.9999999999999999
#
# L = 0.01958259095470638
# m = 0.8999999999999999
#
# L = 0.0221834265555768
# m = 0.9999999999999999
#
# L = 0.01954122006015187
# m = 0.8999999999999999
#
# L = 0.022236211247634887
# m = 0.9999999999999999
#
# L = 0.019500817801278318
# m = 0.8999999999999999
#
# L = 0.02228822300959084
# m = 0.9999999999999999
#
# L = 0.019461358007984854
# m = 0.8999999999999999
#
# L = 0.02233946895782483
# m = 0.9999999999999999
#
# L = 0.019422815386935525
# m = 0.8999999999999999
#
# L = 0.022389956261311763
# m = 0.9999999999999999
#
# L = 0.019385165484070453
# m = 0.8999999999999999
#
# L = 0.02243969213850969
# m = 0.9999999999999999
#
# L = 0.019348384649100107
# m = 0.8999999999999999
#
# L = 0.022488683854194825
# m = 0.9999999999999999
#
# L = 0.019312450001858283
# m = 0.8999999999999999
#
# L = 0.022536938716253854
# m = 0.9999999999999999
#
# L = 0.019277339400399593
# m = 0.8999999999999999
#
# L = 0.022584464072442835
# m = 0.9999999999999999
#
# L = 0.01924303141073484
# m = 0.8999999999999999
#
# L = 0.022631267307122775
# m = 0.9999999999999999
#
# L = 0.019209505278104333
# m = 0.8999999999999999
#
# L = 0.02267735583797955
# m = 0.9999999999999999
#
# L = 0.01917674089969786
# m = 0.8999999999999999
#
# L = 0.022722737112736983
# m = 0.9999999999999999
#
# L = 0.019144718798734084
# m = 0.8999999999999999
#
# L = 0.022767418605870872
# m = 0.9999999999999999
#
# L = 0.019113420099820113
# m = 0.8999999999999999
#
# L = 0.022811407815330552
# m = 0.9999999999999999
#
# L = 0.019082826505515856
# m = 0.8999999999999999
#
# L = 0.022854712259275517
# m = 0.9999999999999999
#
# L = 0.01905292027403346
# m = 0.8999999999999999
#
# L = 0.02289733947283217
# m = 0.9999999999999999
#
# L = 0.019023684198006853
# m = 0.8999999999999999
#
# L = 0.022939297004878123
# m = 0.9999999999999999
#
# L = 0.018995101584270174
# m = 0.8999999999999999
#
# L = 0.022980592414858347
# m = 0.9999999999999999
#
# L = 0.01896715623458808
# m = 0.8999999999999999
#
# L = 0.023021233269638026
# m = 0.9999999999999999
#
# L = 0.01893983242728513
# m = 0.8999999999999999
#
# L = 0.0230612271403982
# m = 0.9999999999999999
#
# L = 0.01891311489972375
# m = 0.8999999999999999
#
# L = 0.023100581599576408
# m = 0.9999999999999999
#
# L = 0.01888698883158447
# m = 0.8999999999999999
#
# L = 0.02313930421785844
# m = 0.9999999999999999
#
# L = 0.01886143982890448
# m = 0.8999999999999999
#
# L = 0.02317740256122269
# m = 0.9999999999999999
#
# L = 0.01883645390883353
# m = 0.8999999999999999
#
# L = 0.02321488418804224
# m = 0.9999999999999999
#
# L = 0.018812017485068736
# m = 0.8999999999999999
#
# L = 0.023251756646246104
# m = 0.9999999999999999
#
# L = 0.01878811735393186
# m = 0.8999999999999999
#
# L = 0.02328802747054353
# m = 0.9999999999999999
#
# L = 0.01876474068105567
# m = 0.8999999999999999
#
# L = 0.023323704179712558
# m = 0.9999999999999999
#
# L = 0.018741874988647017
# m = 0.8999999999999999
#
# L = 0.023358794273956065
# m = 0.9999999999999999
#
# L = 0.01871950814329683
# m = 0.8999999999999999
#
# L = 0.023393305232326057
# m = 0.9999999999999999
#
# L = 0.01869762834430903
# m = 0.8999999999999999
#
# L = 0.023427244510219193
# m = 0.9999999999999999
#
# L = 0.0186762241125215
# m = 0.8999999999999999
#
# L = 0.023460619536942923
# m = 0.9999999999999999
#
# L = 0.018655284279594554
# m = 0.8999999999999999
#
# L = 0.023493437713355506
# m = 0.9999999999999999
#
# L = 0.018634797977743187
# m = 0.8999999999999999
#
# L = 0.023525706409579492
# m = 0.9999999999999999
#
# L = 0.018614754629890953
# m = 0.8999999999999999
#
# L = 0.023557432962789566
# m = 0.9999999999999999
#
# L = 0.01859514394022458
# m = 0.8999999999999999
#
# L = 0.023588624675075807
# m = 0.9999999999999999
#
# L = 0.018575955885130026
# m = 0.8999999999999999
#
# L = 0.02361928881138232
# m = 0.9999999999999999
#
# L = 0.018557180704490823
# m = 0.8999999999999999
#
# L = 0.023649432597521496
# m = 0.9999999999999999
#
# L = 0.018538808893331635
# m = 0.8999999999999999
#
# L = 0.0236790632182642
# m = 0.9999999999999999
#
# L = 0.018520831193790218
# m = 0.8999999999999999
#
# L = 0.023708187815505058
# m = 0.9999999999999999
#
# L = 0.01850323858740254
# m = 0.8999999999999999
#
# L = 0.02373681348650399
# m = 0.9999999999999999
#
# L = 0.018486022287685776
# m = 0.8999999999999999
#
# L = 0.023764947282201843
# m = 0.9999999999999999
#
# L = 0.018469173733005554
# m = 0.8999999999999999
#
# L = 0.02379259620561099
# m = 0.9999999999999999
#
# L = 0.01845268457971442
# m = 0.8999999999999999
#
# L = 0.02381976721028
# m = 0.9999999999999999
#
# L = 0.018436546695548298
# m = 0.8999999999999999
#
# L = 0.023846467198831253
# m = 0.9999999999999999
#
# L = 0.01842075215327028
# m = 0.8999999999999999
#
# L = 0.023872703021570713
# m = 0.9999999999999999
#
# L = 0.018405293224549285
# m = 0.8999999999999999
#
# L = 0.02389848147516984
# m = 0.9999999999999999
#
# L = 0.018390162374064045
# m = 0.8999999999999999
#
# L = 0.023923809301417732
# m = 0.9999999999999999
#
# L = 0.018375352253821753
# m = 0.8999999999999999
#
# L = 0.023948693186042463
# m = 0.9999999999999999
#
# L = 0.018360855697681887
# m = 0.8999999999999999
#
# L = 0.02397313975760116
# m = 0.9999999999999999
#
# L = 0.018346665716076717
# m = 0.8999999999999999
#
# L = 0.02399715558643744
# m = 0.9999999999999999
#
# L = 0.01833277549091911
# m = 0.8999999999999999
#
# L = 0.02402074718370427
# m = 0.9999999999999999
#
# L = 0.018319178370690154
# m = 0.8999999999999999
#
# L = 0.02404392100045189
# m = 0.9999999999999999
#
# L = 0.01830586786569868
# m = 0.8999999999999999
#
# L = 0.02406668342677911
# m = 0.9999999999999999
#
# L = 0.018292837643505155
# m = 0.8999999999999999
#
# L = 0.02408904079104664
# m = 0.9999999999999999
#
# L = 0.01828008152450336
# m = 0.8999999999999999
#
# L = 0.024110999359150526
# m = 0.9999999999999999
#
# L = 0.01826759347765282
# m = 0.8999999999999999
#
# L = 0.0241325653338557
# m = 0.9999999999999999
#
# L = 0.018255367616356183
# m = 0.8999999999999999
#
# L = 0.02415374485418635
# m = 0.9999999999999999
#
# L = 0.018243398194475006
# m = 0.8999999999999999
#
# L = 0.024174543994873086
# m = 0.9999999999999999
#
# L = 0.01823167960247873
# m = 0.8999999999999999
#
# L = 0.024194968765854884
# m = 0.9999999999999999
#
# L = 0.018220206363721195
# m = 0.8999999999999999
#
# L = 0.024215025111833974
# m = 0.9999999999999999
#
# L = 0.01820897313083952
# m = 0.8999999999999999
#
# L = 0.02423471891188295
# m = 0.9999999999999999
#
# L = 0.018197974682270617
# m = 0.8999999999999999
#
# L = 0.02425405597910183
# m = 0.9999999999999999
#
# L = 0.018187205918880428
# m = 0.8999999999999999
#
# L = 0.024273042060324074
# m = 0.9999999999999999
#
# L = 0.01817666186070167
# m = 0.8999999999999999
#
# L = 0.02429168283586981
# m = 0.9999999999999999
#
# L = 0.018166337643775614
# m = 0.8999999999999999
#
# L = 0.024309983919344677
# m = 0.9999999999999999
#
# L = 0.01815622851709394
# m = 0.8999999999999999
#
# L = 0.024327950857483387
# m = 0.9999999999999999
#
# L = 0.01814632983963702
# m = 0.8999999999999999
#
# L = 0.024345589130035112
# m = 0.9999999999999999
#
# L = 0.018136637077504337
# m = 0.8999999999999999
#
# L = 0.024362904149691413
# m = 0.9999999999999999
#
# L = 0.0181271458011344
# m = 0.8999999999999999
#
# L = 0.02437990126205291
# m = 0.9999999999999999
#
# L = 0.018117851682609938
# m = 0.8999999999999999
#
# L = 0.024396585745634844
# m = 0.9999999999999999
#
# L = 0.018108750493045618
# m = 0.8999999999999999
#
# L = 0.024412962811909484
# m = 0.9999999999999999
#
# L = 0.018099838100055318
# m = 0.8999999999999999
#
# L = 0.024429037605384032
# m = 0.9999999999999999
#
# L = 0.018091110465295688
# m = 0.8999999999999999
#
# L = 0.024444815203712493
# m = 0.9999999999999999
#
# L = 0.01808256364208326
# m = 0.8999999999999999
#
# L = 0.02446030061784078
# m = 0.9999999999999999
#
# L = 0.01807419377308291
# m = 0.8999999999999999
#
# L = 0.024475498792182495
# m = 0.9999999999999999
#
# L = 0.018065997088064136
# m = 0.8999999999999999
#
# L = 0.024490414604825164
# m = 0.9999999999999999
#
# L = 0.018057969901723998
# m = 0.8999999999999999
#
# L = 0.02450505286776556
# m = 0.9999999999999999
#
# L = 0.018050108611572937
# m = 0.8999999999999999
#
# L = 0.024519418327171572
# m = 0.9999999999999999
#
# L = 0.018042409695882566
# m = 0.8999999999999999
#
# L = 0.02453351566367135
# m = 0.9999999999999999
#
# L = 0.018034869711692266
# m = 0.8999999999999999
#
# L = 0.02454734949266659
# m = 0.9999999999999999
#
# L = 0.018027485292873173
# m = 0.8999999999999999
#
# L = 0.024560924364670045
# m = 0.9999999999999999
#
# L = 0.018020253148247123
# m = 0.8999999999999999
#
# L = 0.02457424476566556
# m = 0.9999999999999999
#
# L = 0.01801317005975906
# m = 0.8999999999999999
#
# L = 0.02458731511748949
# m = 0.9999999999999999
#
# L = 0.018006232880700888
# m = 0.8999999999999999
#
# L = 0.024600139778232534
# m = 0.9999999999999999
#
# L = 0.017999438533984804
# m = 0.8999999999999999
#
# L = 0.02461272304266082
# m = 0.9999999999999999
#
# L = 0.01799278401046506
# m = 0.8999999999999999
#
# L = 0.024625069142655002
# m = 0.9999999999999999
#
# L = 0.017986266367305923
# m = 0.8999999999999999
#
# L = 0.02463718224766694
# m = 0.9999999999999999
#
# L = 0.017979882726394482
# m = 0.8999999999999999
#
# L = 0.02464906646519196
# m = 0.9999999999999999
#
# L = 0.017973630272797195
# m = 0.8999999999999999
#
# L = 0.0246607258412566
# m = 0.9999999999999999
#
# L = 0.017967506253258058
# m = 0.8999999999999999
#
# L = 0.024672164360920634
# m = 0.9999999999999999
#
# L = 0.017961507974737848
# m = 0.8999999999999999
#
# L = 0.024683385948792408
# m = 0.9999999999999999
#
# L = 0.017955632802992186
# m = 0.8999999999999999
#
# L = 0.024694394469556052
# m = 0.9999999999999999
#
# L = 0.017949878161188225
# m = 0.8999999999999999
#
# L = 0.024705193728511127
# m = 0.9999999999999999
#
# L = 0.01794424152855777
# m = 0.8999999999999999
#
# L = 0.024715787472122032
# m = 0.9999999999999999
#
# L = 0.017938720439086356
# m = 0.8999999999999999
#
# L = 0.024726179388578243
# m = 0.9999999999999999
#
# L = 0.01793331248023674
# m = 0.8999999999999999
#
# L = 0.024736373108362682
# m = 0.9999999999999999
#
# L = 0.017928015291706127
# m = 0.8999999999999999
#
# L = 0.024746372204829194
# m = 0.9999999999999999
#
# L = 0.01792282656421552
# m = 0.8999999999999999
#
# L = 0.024756180194787404
# m = 0.9999999999999999
#
# L = 0.01791774403833093
# m = 0.8999999999999999
#
# L = 0.024765800539094312
# m = 0.9999999999999999
#
# L = 0.017912765503314613
# m = 0.8999999999999999
#
# L = 0.024775236643252284
# m = 0.9999999999999999
#
# L = 0.017907888796006445
# m = 0.8999999999999999
#
# L = 0.02478449185801261
# m = 0.9999999999999999
#
# L = 0.017903111799733484
# m = 0.8999999999999999
#
# L = 0.02479356947998391
# m = 0.9999999999999999
#
# L = 0.017898432443247632
# m = 0.8999999999999999
#
# L = 0.02480247275224512
# m = 0.9999999999999999
#
# L = 0.017893848699690178
# m = 0.8999999999999999
#
# L = 0.024811204864962005
# m = 0.9999999999999999
#
# L = 0.01788935858558261
# m = 0.8999999999999999
#
# L = 0.024819768956006686
# m = 0.9999999999999999
#
# L = 0.017884960159842724
# m = 0.8999999999999999
#
# L = 0.024828168111580458
# m = 0.9999999999999999
#
# L = 0.01788065152282559
# m = 0.8999999999999999
#
# L = 0.024836405366838125
# m = 0.9999999999999999
#
# L = 0.0178764308153882
# m = 0.8999999999999999
#
# L = 0.024844483706514098
# m = 0.9999999999999999
#
# L = 0.017872296217977677
# m = 0.8999999999999999
#
# L = 0.024852406065550087
# m = 0.9999999999999999
#
# L = 0.017868245949741984
# m = 0.8999999999999999
#
# L = 0.024860175329723035
# m = 0.9999999999999999
#
# L = 0.017864278267662296
# m = 0.8999999999999999
#
# L = 0.024867794336273362
# m = 0.9999999999999999
#
# L = 0.01786039146570716
# m = 0.8999999999999999
#
# L = 0.02487526587453351
# m = 0.9999999999999999
#
# L = 0.017856583874007095
# m = 0.8999999999999999
#
# L = 0.024882592686555457
# m = 0.9999999999999999
#
# L = 0.017852853858049293
# m = 0.8999999999999999
#
# L = 0.0248897774677379
# m = 0.9999999999999999
#
# L = 0.017849199817892052
# m = 0.8999999999999999
#
# L = 0.0248968228674512
# m = 0.9999999999999999
#
# L = 0.017845620187398062
# m = 0.8999999999999999
#
# L = 0.024903731489662156
# m = 0.9999999999999999
#
# L = 0.01784211343348645
# m = 0.8999999999999999
#
# L = 0.02491050589355546
# m = 0.9999999999999999
#
# L = 0.017838678055402405
# m = 0.8999999999999999
#
# L = 0.02491714859415386
# m = 0.9999999999999999
#
# L = 0.017835312584004764
# m = 0.8999999999999999
#
# L = 0.024923662062935423
# m = 0.9999999999999999
#
# L = 0.017832015581070292
# m = 0.8999999999999999
#
# L = 0.02493004872844795
# m = 0.9999999999999999
#
# L = 0.017828785638614612
# m = 0.8999999999999999
#
# L = 0.02493631097692079
# m = 0.9999999999999999
#
# L = 0.017825621378229278
# m = 0.8999999999999999
#
# L = 0.024942451152872434
# m = 0.9999999999999999
#
# L = 0.017822521450434513
# m = 0.8999999999999999
#
# L = 0.024948471559715593
# m = 0.9999999999999999
#
# L = 0.01781948453404717
# m = 0.8999999999999999
#
# L = 0.0249543744603579
# m = 0.9999999999999999
#
# L = 0.017816509335563654
# m = 0.8999999999999999
#
# L = 0.024960162077798977
# m = 0.9999999999999999
#
# L = 0.017813594588557122
# m = 0.8999999999999999
#
# L = 0.024965836595722823
# m = 0.9999999999999999
#
# L = 0.01781073905308888
# m = 0.8999999999999999
#
# L = 0.024971400159086537
# m = 0.9999999999999999
#
# L = 0.01780794151513364
# m = 0.8999999999999999
#
# L = 0.024976854874704045
# m = 0.9999999999999999
#
# L = 0.01780520078601769
# m = 0.8999999999999999
#
# L = 0.02498220281182546
# m = 0.9999999999999999
#
# L = 0.01780251570187064
# m = 0.8999999999999999
#
# L = 0.024987446002711144
# m = 0.9999999999999999
#
# L = 0.017799885123089366
# m = 0.8999999999999999
#
# L = 0.024992586443201587
# m = 0.9999999999999999
#
# L = 0.01779730793381449
# m = 0.8999999999999999
#
# L = 0.024997626093281437
# m = 0.9999999999999999
#
# L = 0.01779478304141902
# m = 0.8999999999999999
#
# L = 0.02500256687763875
# m = 0.9999999999999999
#
# L = 0.01779230937600838
# m = 0.8999999999999999
#
# L = 0.02500741068621892
# m = 0.9999999999999999
#
# L = 0.017789885889932217
# m = 0.8999999999999999
#
# L = 0.025012159374772802
# m = 0.9999999999999999
#
# L = 0.017787511557307012
# m = 0.8999999999999999
#
# L = 0.02501681476540009
# m = 0.9999999999999999
#
# L = 0.017785185373549953
# m = 0.8999999999999999
#
# L = 0.025021378647086086
# m = 0.9999999999999999
#
# L = 0.01778290635492282
# m = 0.8999999999999999
#
# L = 0.025025852776233922
# m = 0.9999999999999999
#
# L = 0.01778067353808682
# m = 0.8999999999999999
#
# L = 0.025030238877190112
# m = 0.9999999999999999
#
# L = 0.017778485979666966
# m = 0.8999999999999999
#
# L = 0.025034538642764857
# m = 0.9999999999999999
#
# L = 0.01777634275582658
# m = 0.8999999999999999
#
# L = 0.025038753734746448
# m = 0.9999999999999999
#
# L = 0.017774242961851205
# m = 0.8999999999999999
#
# L = 0.025042885784409406
# m = 0.9999999999999999
#
# L = 0.017772185711741946
# m = 0.8999999999999999
#
# L = 0.025046936393017197
# m = 0.9999999999999999
#
# L = 0.017770170137817794
# m = 0.8999999999999999
#
# L = 0.02505090713231887
# m = 0.9999999999999999
#
# L = 0.01776819539032696
# m = 0.8999999999999999
#
# L = 0.02505479954503906
# m = 0.9999999999999999
#
# L = 0.017766260637066763
# m = 0.8999999999999999
#
# L = 0.025058615145363238
# m = 0.9999999999999999
#
# L = 0.01776436506301213
# m = 0.8999999999999999
#
# L = 0.025062355419415667
# m = 0.9999999999999999
#
# L = 0.017762507869952083
# m = 0.8999999999999999
#
# L = 0.02506602182573194
# m = 0.9999999999999999
#
# L = 0.01776068827613455
# m = 0.8999999999999999
#
# L = 0.025069615795725586
# m = 0.9999999999999999
#
# L = 0.01775890551591889
# m = 0.8999999999999999
#
# L = 0.025073138734148185
# m = 0.9999999999999999
#
# L = 0.017757158839436096
# m = 0.8999999999999999
#
# L = 0.025076592019543775
# m = 0.9999999999999999
#
# L = 0.017755447512256474
# m = 0.8999999999999999
#
# L = 0.02507997700469684
# m = 0.9999999999999999
#
# L = 0.01775377081506467
# m = 0.8999999999999999
#
# L = 0.02508329501707494
# m = 0.9999999999999999
#
# L = 0.01775212804334185
# m = 0.8999999999999999
#
# L = 0.025086547359264504
# m = 0.9999999999999999
#
# L = 0.01775051850705473
# m = 0.8999999999999999
#
# L = 0.02508973530940105
# m = 0.9999999999999999
#
# L = 0.017748941530351628
# m = 0.8999999999999999
#
# L = 0.025092860121593438
# m = 0.9999999999999999
#
# L = 0.01774739645126478
# m = 0.8999999999999999
#
# L = 0.025095923026341997
# m = 0.9999999999999999
#
# L = 0.017745882621419694
# m = 0.8999999999999999
#
# L = 0.02509892523095092
# m = 0.9999999999999999
#
# L = 0.017744399405750184
# m = 0.8999999999999999
#
# L = 0.025101867919934257
# m = 0.9999999999999999
#
# L = 0.017742946182220155
# m = 0.8999999999999999
#
# L = 0.025104752255416685
# m = 0.9999999999999999
#
# L = 0.01774152234155115
# m = 0.8999999999999999
#
# L = 0.025107579377528128
# m = 0.9999999999999999
#
# L = 0.01774012728695577
# m = 0.8999999999999999
#
# L = 0.025110350404792176
# m = 0.9999999999999999
#
# L = 0.017738760433877114
# m = 0.8999999999999999
#
# L = 0.025113066434509466
# m = 0.9999999999999999
#
# L = 0.017737421209733432
# m = 0.8999999999999999
#
# L = 0.02511572854313499
# m = 0.9999999999999999
#
# L = 0.017736109053668753
# m = 0.8999999999999999
#
# L = 0.02511833778664924
# m = 0.9999999999999999
#
# L = 0.017734823416308623
# m = 0.8999999999999999
#
# L = 0.025120895200924625
# m = 0.9999999999999999
#
# L = 0.01773356375952094
# m = 0.8999999999999999
#
# L = 0.02512340180208556
# m = 0.9999999999999999
#
# L = 0.017732329556182463
# m = 0.8999999999999999
#
# L = 0.02512585858686342
# m = 0.9999999999999999
#
# L = 0.01773112028994968
# m = 0.8999999999999999
#
# L = 0.025128266532945396
# m = 0.9999999999999999
#
# L = 0.01772993545503513
# m = 0.8999999999999999
#
# L = 0.025130626599318907
# m = 0.9999999999999999
#
# L = 0.01772877455598809
# m = 0.8999999999999999
#
# L = 0.02513293972660956
# m = 0.9999999999999999
#
# L = 0.01772763710748033
# m = 0.8999999999999999
#
# L = 0.02513520683741417
# m = 0.9999999999999999
#
# L = 0.017726522634096104
# m = 0.8999999999999999
#
# L = 0.025137428836628953
# m = 0.9999999999999999
#
# L = 0.017725430670126885
# m = 0.8999999999999999
#
# L = 0.025139606611771594
# m = 0.9999999999999999
#
# L = 0.017724360759370276
# m = 0.8999999999999999
#
# L = 0.025141741033298533
# m = 0.9999999999999999
#
# L = 0.017723312454933315
# m = 0.8999999999999999
#
# L = 0.025143832954917594
# m = 0.9999999999999999
#
# L = 0.017722285319039934
# m = 0.8999999999999999
#
# L = 0.02514588321389452
# m = 0.9999999999999999
#
# L = 0.017721278922842497
# m = 0.8999999999999999
#
# L = 0.025147892631355414
# m = 0.9999999999999999
#
# L = 0.017720292846237298
# m = 0.8999999999999999
#
# L = 0.025149862012583495
# m = 0.9999999999999999
#
# L = 0.01771932667768404
# m = 0.8999999999999999
#
# L = 0.025151792147311756
# m = 0.9999999999999999
#
# L = 0.017718380014029103
# m = 0.8999999999999999
#
# L = 0.025153683810009854
# m = 0.9999999999999999
#
# L = 0.017717452460332538
# m = 0.8999999999999999
#
# L = 0.025155537760166716
# m = 0.9999999999999999
#
# L = 0.017716543629698753
# m = 0.8999999999999999
#
# L = 0.02515735474256869
# m = 0.9999999999999999
#
# L = 0.017715653143110563
# m = 0.8999999999999999
#
# L = 0.025159135487572266
# m = 0.9999999999999999
#
# L = 0.017714780629267228
# m = 0.8999999999999999
#
# L = 0.025160880711372676
# m = 0.9999999999999999
#
# L = 0.017713925724425306
# m = 0.8999999999999999
#
# L = 0.02516259111626814
# m = 0.9999999999999999
#
# L = 0.017713088072243283
# m = 0.8999999999999999
#
# L = 0.02516426739091903
# m = 0.9999999999999999
#
# L = 0.017712267323629294
# m = 0.8999999999999999
#
# L = 0.025165910210602837
# m = 0.9999999999999999
#
# L = 0.017711463136592002
# m = 0.8999999999999999
#
# L = 0.025167520237465244
# m = 0.9999999999999999
#
# L = 0.01771067517609485
# m = 0.8999999999999999
#
# L = 0.025169098120765863
# m = 0.9999999999999999
#
# L = 0.017709903113912927
# m = 0.8999999999999999
#
# L = 0.025170644497120927
# m = 0.9999999999999999
#
# L = 0.017709146628493405
# m = 0.8999999999999999
#
# L = 0.02517215999074056
# m = 0.9999999999999999
#
# L = 0.01770840540481832
# m = 0.8999999999999999
#
# L = 0.02517364521366301
# m = 0.9999999999999999
#
# L = 0.017707679134270675
# m = 0.8999999999999999
#
# L = 0.025175100765983897
# m = 0.9999999999999999
#
# L = 0.01770696751450312
# m = 0.8999999999999999
#
# L = 0.025176527236082148
# m = 0.9999999999999999
#
# L = 0.017706270249309364
# m = 0.8999999999999999
#
# L = 0.025177925200841344
# m = 0.9999999999999999
#
# L = 0.017705587048498332
# m = 0.8999999999999999
#
# L = 0.0251792952258677
# m = 0.9999999999999999
#
# L = 0.01770491762777101
# m = 0.8999999999999999
#
# L = 0.02518063786570392
# m = 0.9999999999999999
#
# L = 0.01770426170859972
# m = 0.8999999999999999
#
# L = 0.02518195366403919
# m = 0.9999999999999999
#
# L = 0.017703619018109996
# m = 0.8999999999999999
#
# L = 0.02518324315391549
# m = 0.9999999999999999
#
# L = 0.01770298928896486
# m = 0.8999999999999999
#
# L = 0.025184506857930535
# m = 0.9999999999999999
#
# L = 0.017702372259251573
# m = 0.8999999999999999
#
# L = 0.0251857452884365
# m = 0.9999999999999999
#
# L = 0.017701767672370743
# m = 0.8999999999999999
#
# L = 0.02518695894773578
# m = 0.9999999999999999
#
# L = 0.017701175276927637
# m = 0.8999999999999999
#
# L = 0.025188148328272753
# m = 0.9999999999999999
#
# L = 0.017700594826625754
# m = 0.8999999999999999
#
# L = 0.025189313912822305
# m = 0.9999999999999999
#
# L = 0.017700026080162842
# m = 0.8999999999999999
#
# L = 0.025190456174675073
# m = 0.9999999999999999
#
# L = 0.0176994688011287
# m = 0.8999999999999999
#
# L = 0.025191575577819
# m = 0.9999999999999999
#
# L = 0.017698922757905435
# m = 0.8999999999999999
#
# L = 0.025192672577117933
# m = 0.9999999999999999
#
# L = 0.017698387723569534
# m = 0.8999999999999999
#
# L = 0.025193747618486785
# m = 0.9999999999999999
#
# L = 0.017697863475796136
# m = 0.8999999999999999
#
# L = 0.02519480113906339
# m = 0.9999999999999999
#
# L = 0.017697349796765204
# m = 0.8999999999999999
#
# L = 0.0251958335673775
# m = 0.9999999999999999
#
# L = 0.017696846473069492
# m = 0.8999999999999999
#
# L = 0.025196845323516605
# m = 0.9999999999999999
#
# L = 0.017696353295624894
# m = 0.8999999999999999
#
# L = 0.02519783681928851
# m = 0.9999999999999999
#
# L = 0.017695870059581977
# m = 0.8999999999999999
#
# L = 0.025198808458381003
# m = 0.9999999999999999
#
# L = 0.017695396564239917
# m = 0.8999999999999999
#
# L = 0.025199760636518975
# m = 0.9999999999999999
#
# L = 0.01769493261296184
# m = 0.8999999999999999
#
# L = 0.025200693741617923
# m = 0.9999999999999999
#
# L = 0.01769447801309207
# m = 0.8999999999999999
#
# L = 0.02520160815393526
# m = 0.9999999999999999
#
# L = 0.01769403257587515
# m = 0.8999999999999999
#
# L = 0.025202504246218282
# m = 0.9999999999999999
#
# L = 0.017693596116376244
# m = 0.8999999999999999
#
# L = 0.025203382383850066
# m = 0.9999999999999999
#
# L = 0.017693168453403615
# m = 0.8999999999999999
#
# L = 0.025204242924991835
# m = 0.9999999999999999
#
# L = 0.017692749409432173
# m = 0.8999999999999999
#
# L = 0.025205086220723334
# m = 0.9999999999999999
#
# L = 0.017692338810529125
# m = 0.8999999999999999
#
# L = 0.025205912615180345
# m = 0.9999999999999999
#
# L = 0.017691936486280754
# m = 0.8999999999999999
#
# L = 0.02520672244568934
# m = 0.9999999999999999
#
# L = 0.017691542269720913
# m = 0.8999999999999999
#
# L = 0.025207516042900436
# m = 0.9999999999999999
#
# L = 0.017691155997260937
# m = 0.8999999999999999
#
# L = 0.025208293730916598
# m = 0.9999999999999999
#
# L = 0.017690777508620876
# m = 0.8999999999999999
#
# L = 0.025209055827421892
# m = 0.9999999999999999
#
# L = 0.01769040664676242
# m = 0.8999999999999999
#
# L = 0.02520980264380594
# m = 0.9999999999999999
#
# L = 0.01769004325782291
# m = 0.8999999999999999
#
# L = 0.02521053448528715
# m = 0.9999999999999999
#
# L = 0.017689687191050837
# m = 0.8999999999999999
#
# L = 0.025211251651032756
# m = 0.9999999999999999
#
# L = 0.017689338298742648
# m = 0.8999999999999999
#
# L = 0.02521195443427713
# m = 0.9999999999999999
#
# L = 0.01768899643618089
# m = 0.8999999999999999
#
# L = 0.025212643122437838
# m = 0.9999999999999999
#
# L = 0.01768866146157351
# m = 0.8999999999999999
#
# L = 0.02521331799722909
# m = 0.9999999999999999
#
# L = 0.017688333235994586
# m = 0.8999999999999999
#
# L = 0.025213979334773443
# m = 0.9999999999999999
#
# L = 0.017688011623325922
# m = 0.8999999999999999
#
# L = 0.02521462740571114
# m = 0.9999999999999999
#
# L = 0.01768769649020035
# m = 0.8999999999999999
#
# L = 0.02521526247530775
# m = 0.9999999999999999
#
# L = 0.017687387705945697
# m = 0.8999999999999999
#
# L = 0.02521588480355916
# m = 0.9999999999999999
#
# L = 0.01768708514253017
# m = 0.8999999999999999
#
# L = 0.02521649464529495
# m = 0.9999999999999999
#
# L = 0.01768678867450889
# m = 0.8999999999999999
#
# L = 0.02521709225028
# m = 0.9999999999999999
#
# L = 0.01768649817897125
# m = 0.8999999999999999
#
# L = 0.02521767786331351
# m = 0.9999999999999999
#
# L = 0.01768621353548972
# m = 0.8999999999999999
#
# L = 0.02521825172432679
# m = 0.9999999999999999
#
# L = 0.017685934626069294
# m = 0.8999999999999999
#
# L = 0.025218814068478788
# m = 0.9999999999999999
#
# L = 0.01768566133509841
# m = 0.8999999999999999
#
# L = 0.025219365126249834
# m = 0.9999999999999999
#
# L = 0.017685393549300408
# m = 0.8999999999999999
#
# L = 0.025219905123533944
# m = 0.9999999999999999
#
# L = 0.017685131157686416
# m = 0.8999999999999999
#
# L = 0.025220434281728495
# m = 0.9999999999999999
#
# L = 0.017684874051508863
# m = 0.8999999999999999
#
# L = 0.02522095281782343
# m = 0.9999999999999999
#
# L = 0.017684622124216037
# m = 0.8999999999999999
#
# L = 0.025221460944487403
# m = 0.9999999999999999
#
# L = 0.017684375271407808
# m = 0.8999999999999999
#
# L = 0.02522195887015346
# m = 0.9999999999999999
#
# L = 0.01768413339079178
# m = 0.8999999999999999
#
# L = 0.02522244679910207
# m = 0.9999999999999999
#
# L = 0.01768389638214084
# m = 0.8999999999999999
#
# L = 0.025222924931543357
# m = 0.9999999999999999
#
# L = 0.017683664147251133
# m = 0.8999999999999999
#
# L = 0.025223393463697202
# m = 0.9999999999999999
#
# L = 0.017683436589901232
# m = 0.8999999999999999
#
# L = 0.025223852587872016
# m = 0.9999999999999999
#
# L = 0.01768321361581198
# m = 0.8999999999999999
#
# L = 0.025224302492542164
# m = 0.9999999999999999
#
# L = 0.01768299513260715
# m = 0.8999999999999999
#
# L = 0.02522474336242329
# m = 0.9999999999999999
#
# L = 0.017682781049774932
# m = 0.8999999999999999
#
# L = 0.02522517537854699
# m = 0.9999999999999999
#
# L = 0.0176825712786302
# m = 0.8999999999999999
#
# L = 0.025225598718333353
# m = 0.9999999999999999
#
# L = 0.017682365732277557
# m = 0.8999999999999999
#
# L = 0.0252260135556625
# m = 0.9999999999999999
#
# L = 0.01768216432557513
# m = 0.8999999999999999
#
# L = 0.02522642006094465
# m = 0.9999999999999999
#
# L = 0.01768196697509903
# m = 0.8999999999999999
#
# L = 0.02522681840118865
# m = 0.9999999999999999
#
# L = 0.01768177359910873
# m = 0.8999999999999999
#
# L = 0.02522720874006942
# m = 0.9999999999999999
#
# L = 0.01768158411751292
# m = 0.8999999999999999
#
# L = 0.02522759123799371
# m = 0.9999999999999999
#
# L = 0.01768139845183611
# m = 0.8999999999999999
#
# L = 0.025227966052165356
# m = 0.9999999999999999
#
# L = 0.017681216525186033
# m = 0.8999999999999999
#
# L = 0.025228333336648222
# m = 0.9999999999999999
#
# L = 0.017681038262221675
# m = 0.8999999999999999
#
# L = 0.02522869324242864
# m = 0.9999999999999999
#
# L = 0.01768086358912174
# m = 0.8999999999999999
#
# L = 0.02522904591747655
# m = 0.9999999999999999
#
# L = 0.01768069243355411
# m = 0.8999999999999999
#
# L = 0.025229391506804956
# m = 0.9999999999999999
#
# L = 0.017680524724645638
# m = 0.8999999999999999
#
# L = 0.02522973015252914
# m = 0.9999999999999999
#
# L = 0.017680360392952635
# m = 0.8999999999999999
#
# L = 0.025230061993923608
# m = 0.9999999999999999
#
# L = 0.01768019937043204
# m = 0.8999999999999999
#
# L = 0.02523038716747885
# m = 0.9999999999999999
#
# L = 0.01768004159041314
# m = 0.8999999999999999
#
# L = 0.02523070580695638
# m = 0.9999999999999999
#
# L = 0.01767988698756975
# m = 0.8999999999999999
#
# L = 0.02523101804344326
# m = 0.9999999999999999
#
# L = 0.017679735497893045
# m = 0.8999999999999999
#
# L = 0.025231324005404714
# m = 0.9999999999999999
#
# L = 0.017679587058665062
# m = 0.8999999999999999
#
# L = 0.025231623818736844
# m = 0.9999999999999999
#
# L = 0.017679441608432496
# m = 0.8999999999999999
#
# L = 0.02523191760681719
# m = 0.9999999999999999
#
# L = 0.017679299086981175
# m = 0.8999999999999999
#
# L = 0.02523220549055508
# m = 0.9999999999999999
#
# L = 0.01767915943531108
# m = 0.8999999999999999
#
# L = 0.025232487588440555
# m = 0.9999999999999999
#
# L = 0.01767902259561177
# m = 0.8999999999999999
#
# L = 0.025232764016592732
# m = 0.9999999999999999
#
# L = 0.01767888851123841
# m = 0.8999999999999999
#
# L = 0.02523303488880671
# m = 0.9999999999999999
#
# L = 0.017678757126688108
# m = 0.8999999999999999
#
# L = 0.025233300316599875
# m = 0.9999999999999999
#
# L = 0.017678628387576997
# m = 0.8999999999999999
#
# L = 0.02523356040925743
# m = 0.9999999999999999
#
# L = 0.017678502240617636
# m = 0.8999999999999999
#
# L = 0.025233815273876588
# m = 0.9999999999999999
#
# L = 0.017678378633596704
# m = 0.8999999999999999
#
# L = 0.02523406501541029
# m = 0.9999999999999999
#
# L = 0.017678257515353464
# m = 0.8999999999999999
#
# L = 0.025234309736709974
# m = 0.9999999999999999
#
# L = 0.017678138835758472
# m = 0.8999999999999999
#
# L = 0.025234549538567286
# m = 0.9999999999999999
#
# L = 0.017678022545692774
# m = 0.8999999999999999
#
# L = 0.025234784519755075
# m = 0.9999999999999999
#
# L = 0.017677908597027506
# m = 0.8999999999999999
#
# L = 0.025235014777067993
# m = 0.9999999999999999
#
# L = 0.017677796942603796
# m = 0.8999999999999999
#
# L = 0.025235240405361476
# m = 0.9999999999999999
#
# L = 0.017677687536213408
# m = 0.8999999999999999
#
# L = 0.02523546149759074
# m = 0.9999999999999999
#
# L = 0.017677580332579292
# m = 0.8999999999999999
#
# L = 0.025235678144848533
# m = 0.9999999999999999
#
# L = 0.01767747528733704
# m = 0.8999999999999999
#
# L = 0.025235890436402234
# m = 0.9999999999999999
#
# L = 0.017677372357016302
# m = 0.8999999999999999
#
# L = 0.025236098459730433
# m = 0.9999999999999999
#
# L = 0.017677271499022786
# m = 0.8999999999999999
#
# L = 0.02523630230055852
# m = 0.9999999999999999
#
# L = 0.0176771726716206
# m = 0.8999999999999999
#
# L = 0.025236502042893648
# m = 0.9999999999999999
#
# L = 0.017677075833914948
# m = 0.8999999999999999
#
# L = 0.02523669776905911
# m = 0.9999999999999999
#
# L = 0.017676980945835058
# m = 0.8999999999999999
#
# L = 0.025236889559727933
# m = 0.9999999999999999
#
# L = 0.017676887968117727
# m = 0.8999999999999999
#
# L = 0.025237077493955738
# m = 0.9999999999999999
#
# L = 0.01767679686229085
# m = 0.8999999999999999
#
# L = 0.025237261649213107
# m = 0.9999999999999999
#
# L = 0.017676707590657596
# m = 0.8999999999999999
#
# L = 0.025237442101417398
# m = 0.9999999999999999
#
# L = 0.01767662011628069
# m = 0.8999999999999999
#
# L = 0.025237618924963484
# m = 0.9999999999999999
#
# L = 0.017676534402967084
# m = 0.8999999999999999
#
# L = 0.025237792192754283
# m = 0.9999999999999999
#
# L = 0.01767645041525301
# m = 0.8999999999999999
#
# L = 0.02523796197623083
# m = 0.9999999999999999
#
# L = 0.01767636811838927
# m = 0.8999999999999999
#
# L = 0.0252381283454009
# m = 0.9999999999999999
#
# L = 0.017676287478326703
# m = 0.8999999999999999
#
# L = 0.025238291368868408
# m = 0.9999999999999999
#
# L = 0.017676208461702262
# m = 0.8999999999999999
#
# L = 0.025238451113860742
# m = 0.9999999999999999
#
# L = 0.01767613103582497
# m = 0.8999999999999999
#
# L = 0.025238607646256954
# m = 0.9999999999999999
#
# L = 0.01767605516866248
# m = 0.8999999999999999
#
# L = 0.025238761030614076
# m = 0.9999999999999999
#
# L = 0.017675980828827858
# m = 0.8999999999999999
#
# L = 0.025238911330194153
# m = 0.9999999999999999
#
# L = 0.017675907985566376
# m = 0.8999999999999999
#
# L = 0.02523905860698974
# m = 0.9999999999999999
#
# L = 0.01767583660874294
# m = 0.8999999999999999
#
# L = 0.025239202921749377
# m = 0.9999999999999999
#
# L = 0.017675766668829546
# m = 0.8999999999999999
#
# L = 0.025239344334002618
# m = 0.9999999999999999
#
# L = 0.017675698136892973
# m = 0.8999999999999999
#
# L = 0.025239482902084425
# m = 0.9999999999999999
#
# L = 0.017675630984582875
# m = 0.8999999999999999
#
# L = 0.02523961868315875
# m = 0.9999999999999999
#
# L = 0.017675565184119984
# m = 0.8999999999999999
#
# L = 0.025239751733242374
# m = 0.9999999999999999
#
# L = 0.017675500708284574
# m = 0.8999999999999999
#
# L = 0.025239882107227687
# m = 0.9999999999999999
#
# L = 0.017675437530405305
# m = 0.8999999999999999
#
# L = 0.02524000985890516
# m = 0.9999999999999999
#
# L = 0.01767537562434803
# m = 0.8999999999999999
#
# L = 0.025240135040985455
# m = 0.9999999999999999
#
# L = 0.01767531496450495
# m = 0.8999999999999999
#
# L = 0.025240257705121127
# m = 0.9999999999999999
#
# L = 0.017675255525784184
# m = 0.8999999999999999
#
# L = 0.02524037790192763
# m = 0.9999999999999999
#
# L = 0.017675197283599182
# m = 0.8999999999999999
#
# L = 0.02524049568100418
# m = 0.9999999999999999
#
# L = 0.017675140213858617
# m = 0.8999999999999999
#
# L = 0.02524061109095431
# m = 0.9999999999999999
#
# L = 0.017675084292956403
# m = 0.8999999999999999
#
# L = 0.025240724179405382
# m = 0.9999999999999999
#
# L = 0.017675029497761886
# m = 0.8999999999999999
#
# L = 0.025240834993028524
# m = 0.9999999999999999
#
# L = 0.017674975805610373
# m = 0.8999999999999999
#
# L = 0.02524094357755759
# m = 0.9999999999999999
#
# L = 0.017674923194293507
# m = 0.8999999999999999
#
# L = 0.025241049977808048
# m = 0.9999999999999999
#
# L = 0.01767487164205032
# m = 0.8999999999999999
#
# L = 0.0252411542376952
# m = 0.9999999999999999
#
# L = 0.01767482112755813
# m = 0.8999999999999999
#
# L = 0.02524125640025254
# m = 0.9999999999999999
#
# L = 0.017674771629923567
# m = 0.8999999999999999
#
# L = 0.025241356507649197
# m = 0.9999999999999999
#
# L = 0.017674723128674137
# m = 0.8999999999999999
#
# L = 0.025241454601207098
# m = 0.9999999999999999
#
# L = 0.01767467560374967
# m = 0.8999999999999999
#
# L = 0.025241550721418437
# m = 0.9999999999999999
#
# L = 0.017674629035493883
# m = 0.8999999999999999
#
# L = 0.025241644907961863
# m = 0.9999999999999999
#
# L = 0.017674583404646466
# m = 0.8999999999999999
#
# L = 0.025241737199719016
# m = 0.9999999999999999
#
# L = 0.017674538692334898
# m = 0.8999999999999999
#
# L = 0.025241827634790458
# m = 0.9999999999999999
#
# L = 0.01767449488006673
# m = 0.8999999999999999
#
# L = 0.025241916250511164
# m = 0.9999999999999999
#
# L = 0.017674451949721927
# m = 0.8999999999999999
#
# L = 0.025242003083466334
# m = 0.9999999999999999
#
# L = 0.017674409883545385
# m = 0.8999999999999999
#
# L = 0.025242088169505773
# m = 0.9999999999999999
#
# L = 0.01767436866413952
# m = 0.8999999999999999
#
# L = 0.02524217154375935
# m = 0.9999999999999999
#
# L = 0.017674328274457047
# m = 0.8999999999999999
#
# L = 0.025242253240650738
# m = 0.9999999999999999
#
# L = 0.017674288697794013
# m = 0.8999999999999999
#
# L = 0.02524233329391228
# m = 0.9999999999999999
#
# L = 0.017674249917782853
# m = 0.8999999999999999
#
# L = 0.025242411736598188
# m = 0.9999999999999999
#
# L = 0.01767421191838556
# m = 0.8999999999999999
#
# L = 0.02524248860109861
# m = 0.9999999999999999
#
# L = 0.01767417468388703
# m = 0.8999999999999999
#
# L = 0.025242563919152822
# m = 0.9999999999999999
#
# L = 0.017674138198888724
# m = 0.8999999999999999
#
# L = 0.025242637721862284
# m = 0.9999999999999999
#
# L = 0.017674102448302045
# m = 0.8999999999999999
#
# L = 0.025242710039703308
# m = 0.9999999999999999
#
# L = 0.017674067417342263
# m = 0.8999999999999999
#
# L = 0.025242780902539855
# m = 0.9999999999999999
#
# L = 0.017674033091522434
# m = 0.8999999999999999
#
# L = 0.025242850339635508
# m = 0.9999999999999999
#
# L = 0.017673999456647178
# m = 0.8999999999999999
#
# L = 0.025242918379665972
# m = 0.9999999999999999
#
# L = 0.01767396649880706
# m = 0.8999999999999999
#
# L = 0.02524298505073031
# m = 0.9999999999999999
#
# L = 0.017673934204372643
# m = 0.8999999999999999
#
# L = 0.02524305038036305
# m = 0.9999999999999999
#
# L = 0.017673902559988925
# m = 0.8999999999999999
#
# L = 0.025243114395545125
# m = 0.9999999999999999
#
# L = 0.017673871552569893
# m = 0.8999999999999999
#
# L = 0.02524317712271522
# m = 0.9999999999999999
#
# L = 0.01767384116929291
# m = 0.8999999999999999
#
# L = 0.025243238587780496
# m = 0.9999999999999999
#
# L = 0.01767381139759354
# m = 0.8999999999999999
#
# L = 0.025243298816127368
# m = 0.9999999999999999
#
# L = 0.017673782225160396
# m = 0.8999999999999999
#
# L = 0.02524335783263195
# m = 0.9999999999999999
#
# L = 0.01767375363992986
# m = 0.8999999999999999
#
# L = 0.025243415661670387
# m = 0.9999999999999999
#
# L = 0.01767372563008134
# m = 0.8999999999999999
#
# L = 0.025243472327128536
# m = 0.9999999999999999
#
# L = 0.017673698184032128
# m = 0.8999999999999999
#
# L = 0.02524352785241226
# m = 0.9999999999999999
#
# L = 0.01767367129043275
# m = 0.8999999999999999
#
# L = 0.025243582260456775
# m = 0.9999999999999999
#
# L = 0.01767364493816223
# m = 0.8999999999999999
#
# L = 0.025243635573736264
# m = 0.9999999999999999
#
# L = 0.017673619116323605
# m = 0.8999999999999999
#
# L = 0.02524368781427312
# m = 0.9999999999999999
#
# L = 0.017673593814239122
# m = 0.8999999999999999
#
# L = 0.02524373900364674
# m = 0.9999999999999999
#
# L = 0.017673569021446133
# m = 0.8999999999999999
#
# L = 0.025243789163002867
# m = 0.9999999999999999
#
# L = 0.0176735447276926
# m = 0.8999999999999999
#
# L = 0.02524383831306197
# m = 0.9999999999999999
#
# L = 0.017673520922932905
# m = 0.8999999999999999
#
# L = 0.02524388647412801
# m = 0.9999999999999999
#
# L = 0.01767349759732369
# m = 0.8999999999999999
#
# L = 0.025243933666096587
# m = 0.9999999999999999
#
# L = 0.017673474741219698
# m = 0.8999999999999999
#
# L = 0.025243979908463225
# m = 0.9999999999999999
#
# L = 0.017673452345169923
# m = 0.8999999999999999
#
# L = 0.025244025220331597
# m = 0.9999999999999999
#
# L = 0.017673430399913644
# m = 0.8999999999999999
#
# L = 0.025244069620421118
# m = 0.9999999999999999
#
# L = 0.01767340889637653
# m = 0.8999999999999999
#
# L = 0.025244113127074752
# m = 0.9999999999999999
#
# L = 0.01767338782566699
# m = 0.8999999999999999
#
# L = 0.025244155758266665
# m = 0.9999999999999999
#
# L = 0.01767336717907236
# m = 0.8999999999999999
#
# L = 0.025244197531609558
# m = 0.9999999999999999
#
# L = 0.017673346948055463
# m = 0.8999999999999999
#
# L = 0.025244238464361978
# m = 0.9999999999999999
#
# L = 0.017673327124250966
# m = 0.8999999999999999
#
# L = 0.025244278573435343
# m = 0.9999999999999999
#
# L = 0.01767330769946194
# m = 0.8999999999999999
#
# L = 0.025244317875401014
# m = 0.9999999999999999
#
# L = 0.017673288665656484
# m = 0.8999999999999999
#
# L = 0.02524435638649705
# m = 0.9999999999999999
#
# L = 0.01767327001496436
# m = 0.8999999999999999
#
# L = 0.025244394122635083
# m = 0.9999999999999999
#
# L = 0.01767325173967384
# m = 0.8999999999999999
#
# L = 0.025244431099406495
# m = 0.9999999999999999
#
# L = 0.01767323383222836
# m = 0.8999999999999999
#
# L = 0.025244467332089376
# m = 0.9999999999999999
#
# L = 0.01767321628522354
# m = 0.8999999999999999
#
# L = 0.02524450283565431
# m = 0.9999999999999999
#
# L = 0.01767319909140405
# m = 0.8999999999999999
#
# L = 0.02524453762477091
# m = 0.9999999999999999
#
# L = 0.017673182243660615
# m = 0.8999999999999999
#
# L = 0.025244571713813717
# m = 0.9999999999999999
#
# L = 0.017673165735027054
# m = 0.8999999999999999
#
# L = 0.02524460511686819
# m = 0.9999999999999999
#
# L = 0.017673149558677444
# m = 0.8999999999999999
#
# L = 0.025244637847736395
# m = 0.9999999999999999
#
# L = 0.017673133707923318
# m = 0.8999999999999999
#
# L = 0.02524466991994292
# m = 0.9999999999999999
#
# L = 0.017673118176210735
# m = 0.8999999999999999
#
# L = 0.02524470134674031
# m = 0.9999999999999999
#
# L = 0.017673102957117826
# m = 0.8999999999999999
#
# L = 0.025244732141114386
# m = 0.9999999999999999
#
# L = 0.017673088044351935
# m = 0.8999999999999999
#
# L = 0.025244762315789888
# m = 0.9999999999999999
#
# L = 0.01767307343174703
# m = 0.8999999999999999
#
# L = 0.02524479188323569
# m = 0.9999999999999999
#
# L = 0.017673059113261304
# m = 0.8999999999999999
#
# L = 0.025244820855669665
# m = 0.9999999999999999
#
# L = 0.017673045082974556
# m = 0.8999999999999999
#
# L = 0.025244849245064097
# m = 0.9999999999999999
#
# L = 0.017673031335085666
# m = 0.8999999999999999
#
# L = 0.02524487706315035
# m = 0.9999999999999999
#
# L = 0.01767301786391042
# m = 0.8999999999999999
#
# L = 0.02524490432142386
# m = 0.9999999999999999
#
# L = 0.017673004663878934
# m = 0.8999999999999999
#
# L = 0.025244931031148745
# m = 0.9999999999999999
#
# L = 0.017672991729533516
# m = 0.8999999999999999
#
# L = 0.025244957203362593
# m = 0.9999999999999999
#
# L = 0.017672979055526252
# m = 0.8999999999999999
#
# L = 0.025244982848880954
# m = 0.9999999999999999
#
# L = 0.01767296663661702
# m = 0.8999999999999999
#
# L = 0.025245007978301835
# m = 0.9999999999999999
#
# L = 0.017672954467671007
# m = 0.8999999999999999
#
# L = 0.025245032602009995
# m = 0.9999999999999999
#
# L = 0.017672942543656908
# m = 0.8999999999999999
#
# L = 0.025245056730181265
# m = 0.9999999999999999
#
# L = 0.017672930859644647
# m = 0.8999999999999999
#
# L = 0.025245080372786888
# m = 0.9999999999999999
#
# L = 0.01767291941080338
# m = 0.8999999999999999
#
# L = 0.025245103539597476
# m = 0.9999999999999999
#
# L = 0.017672908192399497
# m = 0.8999999999999999
#
# L = 0.02524512624018695
# m = 0.9999999999999999
#
# L = 0.0176728971997947
# m = 0.8999999999999999
#
# L = 0.025245148483936716
# m = 0.9999999999999999
#
# L = 0.01767288642844404
# m = 0.8999999999999999
#
# L = 0.025245170280039562
# m = 0.9999999999999999
#
# L = 0.01767287587389409
# m = 0.8999999999999999
#
# L = 0.02524519163750313
# m = 0.9999999999999999
#
# L = 0.01767286553178102
# m = 0.8999999999999999
#
# L = 0.025245212565154003
# m = 0.9999999999999999
#
# L = 0.017672855397828872
# m = 0.8999999999999999
#
# L = 0.025245233071641077
# m = 0.9999999999999999
#
# L = 0.017672845467847777
# m = 0.8999999999999999
#
# L = 0.025245253165439345
# m = 0.9999999999999999
#
# L = 0.01767283573773212
# m = 0.8999999999999999
#
# L = 0.025245272854853274
# m = 0.9999999999999999
#
# L = 0.017672826203459092
# m = 0.8999999999999999
#
# L = 0.02524529214802013
# m = 0.9999999999999999
#
# L = 0.01767281686108668
# m = 0.8999999999999999
#
# L = 0.0252453110529137
# m = 0.9999999999999999
#
# L = 0.01767280770675231
# m = 0.8999999999999999
#
# L = 0.02524532957734706
# m = 0.9999999999999999
#
# L = 0.017672798736671155
# m = 0.8999999999999999
#
# L = 0.025245347728976422
# m = 0.9999999999999999
#
# L = 0.017672789947134605
# m = 0.8999999999999999
#
# L = 0.025245365515303632
# m = 0.9999999999999999
#
# L = 0.01767278133450864
# m = 0.8999999999999999
#
# L = 0.025245382943679777
# m = 0.9999999999999999
#
# L = 0.017672772895232378
# m = 0.8999999999999999
#
# L = 0.0252454000213081
# m = 0.9999999999999999
#
# L = 0.017672764625816705
# m = 0.8999999999999999
#
# L = 0.02524541675524681
# m = 0.9999999999999999
#
# L = 0.017672756522842642
# m = 0.8999999999999999
#
# L = 0.025245433152412015
# m = 0.9999999999999999
#
# L = 0.0176727485829601
# m = 0.8999999999999999
#
# L = 0.025245449219580926
# m = 0.9999999999999999

# %%
# _ = get_iteration_vs_accuracy_data(X, y, 1000, L=0.001)
