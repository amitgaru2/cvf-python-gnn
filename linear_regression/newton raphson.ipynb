# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from algorithm_gd import forward, loss_fn, r2_score, gradient_m, gradient_c, get_iteration_vs_accuracy_data

# %%
X = [1, 1, 1, 2, 2, 2, 3, 3, 3,  5, 5, 5, 6, 6, 6, 7,7, 7,  9, 9, 9, 10, 10, 10, 11, 11, 11]
y = [2, 2.25, 1.75, 2, 2.25, 1.75, 2, 2.25, 1.75, 6, 6.25, 5.75, 6, 6.25, 5.75, 6, 6.25, 5.75,  10, 9.75, 10.25, 10, 9.75, 10.25, 10, 9.75, 10.25]

# %%
df = pd.read_csv("SOCR-HeightWeight.csv")
df.rename(columns={"Height(Inches)": "X", "Weight(Pounds)": "y"}, inplace=True)
X = df['X'].array
y = df['y'].array

# %%
L0 = 0

# %%
m = 0
step_m = 0.1
c = 0

# %%
iterations = 100

# %%
def newton_raphson_L(L0, m_pred, m, grad_m):
    def f_L(L):
        return m_pred - m + L * grad_m

    def f_L_der(L):
        return grad_m

    numerator = f_L(L0)
    denominator = f_L_der(L0)

    while numerator != 0:
        new_L0 = L0 - numerator/denominator
        numerator = f_L(L0)
        denominator = f_L_der(L0)
        if abs(new_L0 - L0) <= 0.00001:
            L0 = new_L0
            break
        L0 = new_L0

    return L0

# %%
params = {"m": m, "c": c}
X_test = X
y_test = y
y_test_mean = sum(y_test)/len(y_test)

# %%
L = L0
for i in range(1, iterations + 1):
    y_pred = forward(X, params)
    y_test_pred = forward(X_test, params)

    accuracy = r2_score(y_test, y_test_mean, y_test_pred)

    grad_m = gradient_m(X, y, y_pred)
    print("gradient", grad_m)






























































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































    
    grad_c = gradient_c(y, y_pred)

    L0 = L
    
    m_pred = m + step_m
    L_add = newton_raphson_L(L0, m_pred, m, grad_m)

    m_pred = m - step_m
    L_sub = newton_raphson_L(L0, m_pred, m, grad_m)

    print("L_add =", L_add, "L_sub =", L_sub)

    if L_add <= 0 and L_sub <= 0:
        break
    elif L_add >= 0 and L_sub >= 0:
        L = min(L_add, L_sub)
    elif L_add <= 0:
        L = L_sub
    else:
        L = L_add

    print("L =", L)

    m = m - L * grad_m
    c = c - L * grad_c

    print("m =", m)

    params = {"m": m, "c": c}
    print()
# Out:
# L_add = 5.779226985719153e-06 L_sub = -5.779226985719153e-06
# L = 5.779226985719153e-06
# m = 0.1
#
# L_add = 6.1058200224380135e-06 L_sub = -1.7990867030595183e-05
# L = 6.1058200224380135e-06
# m = 0.2
#
# L_add = 6.471536538225142e-06 L_sub = -1.9048893098888295e-05
# L = 6.471536538225142e-06
# m = 0.30000000000000004
#
# L_add = 6.88385449979828e-06 L_sub = -2.0239245537821704e-05
# L = 6.88385449979828e-06
# m = 0.4
#
# L_add = 7.352287317578656e-06 L_sub = -2.1588429134955592e-05
# L = 7.352287317578656e-06
# m = 0.5
#
# L_add = 7.889126952316302e-06 L_sub = -2.3130541222211257e-05
# L = 7.889126952316302e-06
# m = 0.6
#
# L_add = 8.510538220076346e-06 L_sub = -2.4910203392468995e-05
# L = 8.510538220076346e-06
# m = 0.7
#
# L_add = 9.238214495060033e-06 L_sub = -2.6986967210196414e-05
# L = 9.238214495060033e-06
# m = 0.7999999999999999
#
# L_add = 1.0101962234285944e-05 L_sub = -2.9442138963631916e-05
# L = 1.0101962234285944e-05
# m = 0.8999999999999999
#
# L_add = 1.1143884918831256e-05 L_sub = -3.238973207194846e-05
# L = 1.1143884918831256e-05
# m = 0.9999999999999999
#
# L_add = 1.2425453964002774e-05 L_sub = -3.59947928468368e-05
# L = 1.2425453964002774e-05
# m = 1.0999999999999999
#
# L_add = 1.404009264917283e-05 L_sub = -4.0505639262348405e-05
# L = 1.404009264917283e-05
# m = 1.2
#
# L_add = 1.613703680665472e-05 L_sub = -4.6314166262482274e-05
# L = 1.613703680665472e-05
# m = 1.3
#
# L_add = 1.897033185374804e-05 L_sub = -5.4077700514150794e-05
# L = 1.897033185374804e-05
# m = 1.4000000000000001
#
# L_add = 2.3010439122052646e-05 L_sub = -6.499121009785333e-05
# L = 2.3010439122052646e-05
# m = 1.5000000000000002
#
# L_add = 2.9237045611323507e-05 L_sub = -8.148453034469966e-05
# L = 2.9237045611323507e-05
# m = 1.6000000000000003
#
# L_add = 5.093024911610677e-05 L_sub = -0.00010940434033875379
# L = 5.093024911610677e-05
# m = 1.7270599171127587
#
# L_add = 0.00010072290267834235 L_sub = -0.0002025834009105559
# L = 0.00010072290267834235
# m = 1.8598931638821532
#
# L_add = 0.002136880014021691 L_sub = -0.002338325819378376
# L = 0.002136880014021691
# m = 2.0508904134900607
#
# L_add = -0.002256046159540091 L_sub = -0.0020177138685032914

# %%
# _ = get_iteration_vs_accuracy_data(X, y, 1000, L=0.001)
